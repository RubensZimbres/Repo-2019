# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
#pip install pandas-datareader

data=pd.read_csv('/home/rubensvectomobile/Notebooks/Notebooks/Lista_Acoes.csv',sep=';',header=0)
nomes=data.iloc[:,0]
nomes;

# %%
nomes2=[]
for i in range(0,len(nomes)):

    try:
        stock = str(nomes[i])
        source = 'yahoo'

        # Set date range (Google went public August 19, 2004)
        start = datetime.datetime(2015, 7, 23)
        end = datetime.datetime(2019, 7, 23)

        # Collect Google stock data
        goog_df = data.DataReader(stock, source, start, end)
        nomes2.append(stock)
    except:
        stock = str(nomes[i])+'.SA'
        nomes2.append(stock)

# %%
nomes2[0]
# Out:
# 'AALR3.SA'

# %%
from pandas_datareader import data

data2=[]
import time

def extract(inputs):
    try:
        stock = inputs
        source = 'yahoo'

        start = datetime.datetime(2019, 1, 19)
        end = datetime.datetime(2019, 7, 19)
        goog_df = data.DataReader(stock, source, start, end)


        data2.append(list(goog_df['Adj Close']))
    except:
        data2.append([])
        print(stock,'error')
    return data2

# %%
cotacoes=list(map(extract,nomes2))
# Out:
# ALMI11.SA error
# ALUP11.SA error
# ALZR11.SA error
# ATSA11.SA error
# BBSD11.SA error
# BIDI11.SA error
# BIDI3.SA error
# BPAC11.SA error
# BTCR11.SA error
# BZLI11.SA error
# CNES11.SA error
# CRFF11.SA error
# DMAC11.SA error
# EDGA11.SA error
# ENGI11.SA error
# FAED11.SA error
# FEXC11.SA error
# FLRP11.SA error
# FMOF11.SA error
# FVBI11.SA error
# GSFI11.SA error
# GTWR11.SA error
# HBTT11.SA error
# HCRI11.SA error
# HCTR11.SA error
# HGLG11.SA error
# HGPO11.SA error
# HGRU11.SA error
# HMOC11.SA error
# HTMX11.SA error
# HUSC11.SA error
# IBOV11.SA error
# IRDM11.SA error
# JBDU11.SA error
# JBDU12.SA error
# JRDM11.SA error
# KFOF11.SA error
# KLBN11.SA error
# KNHY11.SA error
# LOFT11B.SA error
# LVBI11.SA error
# MAXR11.SA error
# MGFF11.SA error
# NEOE3B.SA error
# NSLU11.SA error
# ORPD11.SA error
# OUCY11.SA error
# OUFF11.SA error
# OULG11B.SA error
# PATC11.SA error
# PPLA11.SA error
# RBDS11.SA error
# RBED11.SA error
# RBRP11.SA error
# RBRR11.SA error
# RBRY11.SA error
# RBVA11.SA error
# RDPD11.SA error
# RECT11.SA error
# RNEW11.SA error
# SANB11.SA error
# SAPR11.SA error
# TAEE11.SA error
# TFOF11.SA error
# TGAR11.SA error
# TIET11.SA error
# TOUR13.SA error
# TRNT11.SA error
# VGIR11.SA error
# VILG11.SA error
# VOTS11.SA error
# VSHO11.SA error
# VTLT11.SA error
# WTSP11B.SA error
# XPHT11.SA error
# XPHT12.SA error
# XPIN11.SA error
# XPLG11.SA error
# XPML11.SA error

# %%
import requests
from bs4 import BeautifulSoup

PE = []
Exp1Y = []
MargemLucro = []
Crescimento4 = []
Debt_Equity = []
UmAno = []


for name in nomes2:

    page = requests.get('https://finance.yahoo.com/quote/{}'.format(name))

    soup = BeautifulSoup(page.text, "html")

    req=soup.find_all(attrs={"class": "Trsdu(0.3s)","data-reactid":"66"})

    for i in req:
        if i.get_text()!=[]:
            PE.append(i.get_text())
        else:
            PE.append(['--'])

# %%
for i in range(0,len(nomes2)):
    try:
        a=pd.Series(data2[i])
        a.plot(kind='line', grid=True, title='{} Adjusted Closes'.format(nomes[i]))
        plt.show()
        print(nomes2[i],'',max(data2[i])/min(data2[i]))
        print('PE',PE[i])
    except:
        pass
# Out:
# AALR3.SA  1.203753676613225
# PE 42.69
# AAPL34.SA  1.460125873000603
# PE 6.60
# ABBV34.SA  1.2948314534802072
# PE 9.24
# ABCB4.SA  1.1553509673421039
# PE N/A
# ABCP11.SA  1.2101209917876998
# PE 25.72
# ABEV3.SA  1.1618814589293798
# PE 48.69
# ABTT34.SA  1.3042164393123226
# PE 102.43
# ACNB34.SA  1.3449579109353156
# PE N/A
# ADHM3.SA  1.5312500640284283
# PE 15.15
# AFLT3.SA  1.418552007398096
# PE 4.67
# AGRO3.SA  1.1266666412353517
# PE N/A
# AHEB3.SA  1.9986675244864296
# PE N/A
# AIGB34.SA  1.4523809353723152
# PE N/A
# ALPA3.SA  1.4642857142857142
# PE 45.35
# ALPA4.SA  1.4839572664659744
# PE 41.93
# ALSC3.SA  1.5459239336650394
# PE 10.80
# ALUP3.SA  1.3657660593601915
# PE 3.51
# ALUP4.SA  1.5458011337927868
# PE N/A
# AMAR3.SA  1.5444444454255908
# PE 53.22
# AMGN34.SA  1.1633709082161439
# PE 154.80
# AMZO34.SA  1.3087159793421312
# PE 3,601.67
# ANIM3.SA  1.2169992526015843
# PE N/A
# APER3.SA  1.5966850281460372
# PE N/A
# ARMT34.SA  1.4786990751731253
# PE N/A
# ARNC34.SA  1.0064529049268514
# PE 32.81
# ARZZ3.SA  1.1903734282471445
# PE 5.64
# ATOM3.SA  1.68789809352462
# PE N/A
# ATTB34.SA  1.2223453476686106
# PE 59.60
# AVON34.SA  2.1052631843123084
# PE N/A
# AXPB34.SA  1.0811628418571957
# PE N/A
# AZEV3.SA  12.934782876860222
# PE 44.13
# AZEV4.SA  4.415204691408287
# PE 35.88
# AZUL4.SA  1.577287028284716
# PE N/A
# B3SA3.SA  1.4333702252458742
# PE 38.19
# BAHI3.SA  1.336283185840708
# PE 8.71
# BALM4.SA  1.1171032751440138
# PE 5.86
# BAUH4.SA  2.2067723869559206
# PE 10.49
# BAZA3.SA  1.4035426657472547
# PE 15.72
# BBAS3.SA  1.2448039390075496
# PE 17.39
# BBDC3.SA  1.2623445960741309
# PE N/A
# BBDC4.SA  1.2069885055000362
# PE 8.12
# BBFI11B.SA  1.3036601897876186
# PE N/A
# BBPO11.SA  1.0983108956326153
