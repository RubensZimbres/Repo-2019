# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
#pip install pandas-datareader

stock = 'ALPA4.SA'
source = 'yahoo'

# Set date range (Google went public August 19, 2004)
start = datetime.datetime(2004, 8, 19)
end = datetime.datetime(2019, 7, 10)

# Collect Google stock data
goog_df = data.DataReader(stock, source, start, end)

dataset = goog_df['Adj Close']
print(len(dataset))
goog_df['Adj Close'].plot(kind='line', grid=True, title='GOOG Adjusted Closes, IPO through 2016')
# Out:
# 2800

# %%
import tensorflow as tf
import pandas as pd  
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow_probability as tfp


dataset = np.array(dataset.astype('float32')).reshape(-1,1)

def norm(x):
    return (x-np.min(x))/(np.max(x)-np.min(x))

#dataset=norm(dataset)

look_back=4
np.random.seed(7)
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.99)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))

def create_dataset(dataset, look_back=look_back):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX

trainY = trainY.reshape(len(trainY), 1)
testY = testY.reshape(len(testY), 1)
trainY

X0=trainX
Y0=trainY
# Out:
# 2772 28

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
tfd = tfp.distributions

class TemporalConvNet(tf.layers.Layer):
    def __init__(self, num_channels, kernel_size=2, dropout=0.2,
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalConvNet, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )
        self.layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            out_channels = num_channels[i]
            self.layers.append(
                TemporalBlock(out_channels, kernel_size, strides=1, dilation_rate=dilation_size,
                              dropout=dropout, name="tblock_{}".format(i))
            )
    
    def call(self, inputs, training=True):
        outputs = inputs
        for layer in self.layers:
            outputs = layer(outputs, training=training)
        return outputs

learning_rate = 0.001
display_step = 10
num_input = 1
num_hidden = 35
num_classes = 1

dropout = 0
kernel_size = 8
levels = 6

class CausalConv1D(tf.layers.Conv1D):
    def __init__(self, filters,
               kernel_size,
               strides=1,
               dilation_rate=1,
               activation=None,
               use_bias=True,
               kernel_initializer=None,
               bias_initializer=tf.zeros_initializer(),
               kernel_regularizer=None,
               bias_regularizer=None,
               activity_regularizer=None,
               kernel_constraint=None,
               bias_constraint=None,
               trainable=True,
               name=None,
               **kwargs):
        super(CausalConv1D, self).__init__(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            padding='valid',
            data_format='channels_last',
            dilation_rate=dilation_rate,
            activation=activation,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
            activity_regularizer=activity_regularizer,
            kernel_constraint=kernel_constraint,
            bias_constraint=bias_constraint,
            trainable=trainable,
            name=name, **kwargs
        )
       
    def call(self, inputs):
        padding = (self.kernel_size[0] - 1) * self.dilation_rate[0]
        inputs = tf.pad(inputs, tf.constant([(0, 0,), (1, 0), (0, 0)]) * padding)
        return super(CausalConv1D, self).call(inputs)



class TemporalBlock(tf.layers.Layer):
    def __init__(self, n_outputs, kernel_size, strides, dilation_rate, dropout=0.1, 
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalBlock, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )        
        self.dropout = dropout
        self.n_outputs = n_outputs
        self.conv1 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv1")
        self.conv2 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv2")
        self.down_sample = None

    
    def build(self, input_shape):
        channel_dim = 2
        self.dropout1 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        self.dropout2 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        if input_shape[channel_dim] != self.n_outputs:
            self.down_sample = tf.layers.Dense(self.n_outputs, activation=None)
    
    def call(self, inputs, training=True):
        x = self.conv1(inputs)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout1(x, training=training)
        x = self.conv2(x)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout2(x, training=training)
        #x = tfp.layers.DistributionLambda(make_distribution_fn=lambda t: tfd.Normal(loc=t, scale=1))(x)
        #x = tf.contrib.layers.layer_norm(x)
        #x = tf.layers.dense(inputs=x,units=3)
        if self.down_sample is not None:
          inputs = self.down_sample(inputs)
        return tf.nn.relu(x)



tf.reset_default_graph()
graph = tf.Graph()
with graph.as_default():
    tf.set_random_seed(2)
    
    X = tf.placeholder("float", [None, look_back,1])
    Y = tf.placeholder("float", [None, num_classes])
    is_training = tf.placeholder("bool")
    
    logits = tf.layers.dense(
        TemporalConvNet([num_hidden] * levels, kernel_size, dropout)(
            X, training=is_training),
        num_classes, activation=None, 
        kernel_initializer=tf.glorot_uniform_initializer()
    )
    print(logits)

    mm,_=tf.nn.moments(tf.reshape(tf.nn.relu(logits),[-1,look_back]),axes=[1])
    prediction=tf.nn.relu(logits)
    
    prediction2 = tf.reshape(tf.cast(mm,tf.float32),[-1,1])
    
    loss_op = tf.reduce_mean(tf.losses.mean_squared_error(
        labels=Y,predictions=prediction2))
    
    accuracy=1-tf.sqrt(loss_op)

    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    train_op = optimizer.minimize(loss_op)


    saver = tf.train.Saver()
    print("All parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.global_variables()]))
    print("Trainable parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()]))

def next_batch(num, data, labels):
    idx = np.arange(0 , len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    return np.asarray(data_shuffle).astype(np.float32), np.asarray(labels_shuffle).astype(np.float32)

log_dir = "/home/rubensvectomobile/BOVESPA/"
tb_writer = tf.summary.FileWriter(log_dir, graph)
config = tf.ConfigProto()
config.gpu_options.allow_growth = False
config.gpu_options.per_process_gpu_memory_fraction = 0.7
best_val_acc = 0.86

training_epochs = 2000
batch_size = X0.shape[0]


X0=X0.reshape(-1,look_back,1)
testX=testX.reshape(-1,look_back,1)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0723 17:39:28.935802 140607277242112 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0723 17:39:29.053519 140607277242112 deprecation.py:506] From /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0723 17:39:30.760887 140607277242112 deprecation.py:323] From <ipython-input-4-e696691e5b91>:140: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0723 17:39:30.820297 140607277242112 deprecation.py:323] From /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Tensor("dense/BiasAdd:0", shape=(?, 4, 1), dtype=float32)
# All parameters: 328200.0
# Trainable parameters: 109446

# %%
with tf.Session(graph=graph, config=config) as sess:
    init = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
    sess.run(init)
    for step in range(1, training_epochs+1):
        Xt, Yt = next_batch(batch_size, X0, Y0)
        batch_x, batch_y = Xt,Yt
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, is_training: True})
        if step % display_step == 0 or step == 1:
            loss, acc = sess.run([loss_op, accuracy], feed_dict={
                X: batch_x, Y: batch_y, is_training: False})
            test_data = testX
            test_label = testY
            val_acc = sess.run(accuracy, feed_dict={X: test_data, Y: test_label, is_training: False})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.4f}".format(acc) + ", Test Accuracy= " + \
                  "{:.4f}".format(val_acc))
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                save_path = saver.save(sess, "/home/rubensvectomobile/BOVESPA/model.ckpt")
                print("Model saved in path: %s" % save_path)
    pred00 = sess.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = sess.run([prediction2], feed_dict={X: test_data, is_training: False})
# Out:
# Step 1, Minibatch Loss= 0.1047, Training Accuracy= 0.6764, Test Accuracy= 0.0965
# Step 10, Minibatch Loss= 0.0170, Training Accuracy= 0.8695, Test Accuracy= 0.4007
# Step 20, Minibatch Loss= 0.0070, Training Accuracy= 0.9162, Test Accuracy= 0.6125
# Step 30, Minibatch Loss= 0.0021, Training Accuracy= 0.9541, Test Accuracy= 0.7907
# Step 40, Minibatch Loss= 0.0008, Training Accuracy= 0.9718, Test Accuracy= 0.8326
# Step 50, Minibatch Loss= 0.0004, Training Accuracy= 0.9792, Test Accuracy= 0.8582
# Step 60, Minibatch Loss= 0.0002, Training Accuracy= 0.9850, Test Accuracy= 0.8667
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 70, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.8719
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 80, Minibatch Loss= 0.0002, Training Accuracy= 0.9870, Test Accuracy= 0.8848
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 90, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.8936
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 100, Minibatch Loss= 0.0001, Training Accuracy= 0.9881, Test Accuracy= 0.8962
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 110, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.8967
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 120, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.9022
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 130, Minibatch Loss= 0.0001, Training Accuracy= 0.9892, Test Accuracy= 0.9052
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 140, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.9067
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 150, Minibatch Loss= 0.0004, Training Accuracy= 0.9792, Test Accuracy= 0.8795
# Step 160, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.8923
# Step 170, Minibatch Loss= 0.0001, Training Accuracy= 0.9881, Test Accuracy= 0.9188
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 180, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9103
# Step 190, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9095
# Step 200, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9102
# Step 210, Minibatch Loss= 0.0004, Training Accuracy= 0.9796, Test Accuracy= 0.9351
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 220, Minibatch Loss= 0.0003, Training Accuracy= 0.9818, Test Accuracy= 0.9294
# Step 230, Minibatch Loss= 0.0002, Training Accuracy= 0.9843, Test Accuracy= 0.8811
# Step 240, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.8958
# Step 250, Minibatch Loss= 0.0002, Training Accuracy= 0.9870, Test Accuracy= 0.9140
# Step 260, Minibatch Loss= 0.0001, Training Accuracy= 0.9880, Test Accuracy= 0.8953
# Step 270, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9138
# Step 280, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9184
# Step 290, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9153
# Step 300, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9264
# Step 310, Minibatch Loss= 0.0003, Training Accuracy= 0.9838, Test Accuracy= 0.8803
# Step 320, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9048
# Step 330, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.8748
# Step 340, Minibatch Loss= 0.0001, Training Accuracy= 0.9892, Test Accuracy= 0.8928
# Step 350, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9159
# Step 360, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9159
# Step 370, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9189
# Step 380, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9290
# Step 390, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9307
# Step 400, Minibatch Loss= 0.0004, Training Accuracy= 0.9795, Test Accuracy= 0.9450
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 410, Minibatch Loss= 0.0001, Training Accuracy= 0.9887, Test Accuracy= 0.9225
# Step 420, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9039
# Step 430, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9148
# Step 440, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9180
# Step 450, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9271
# Step 460, Minibatch Loss= 0.0004, Training Accuracy= 0.9798, Test Accuracy= 0.9432
# Step 470, Minibatch Loss= 0.0002, Training Accuracy= 0.9870, Test Accuracy= 0.9215
# Step 480, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9111
# Step 490, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9112
# Step 500, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9182
# Step 510, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9243
# Step 520, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9290
# Step 530, Minibatch Loss= 0.0001, Training Accuracy= 0.9888, Test Accuracy= 0.9396
# Step 540, Minibatch Loss= 0.0004, Training Accuracy= 0.9793, Test Accuracy= 0.8890
# Step 550, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9051
# Step 560, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9222
# Step 570, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9211
# Step 580, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9254
# Step 590, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9329
# Step 600, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9323
# Step 610, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9359
# Step 620, Minibatch Loss= 0.0007, Training Accuracy= 0.9741, Test Accuracy= 0.9525
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 630, Minibatch Loss= 0.0002, Training Accuracy= 0.9871, Test Accuracy= 0.9195
# Step 640, Minibatch Loss= 0.0001, Training Accuracy= 0.9883, Test Accuracy= 0.8940
# Step 650, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9272
# Step 660, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9315
# Step 670, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9321
# Step 680, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9362
# Step 690, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9393
# Step 700, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9381
# Step 710, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9350
# Step 720, Minibatch Loss= 0.0007, Training Accuracy= 0.9732, Test Accuracy= 0.8782
# Step 730, Minibatch Loss= 0.0003, Training Accuracy= 0.9817, Test Accuracy= 0.8830
# Step 740, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9189
# Step 750, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9244
# Step 760, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9268
# Step 770, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9319
# Step 780, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9380
# Step 790, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9417
# Step 800, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9440
# Step 810, Minibatch Loss= 0.0003, Training Accuracy= 0.9825, Test Accuracy= 0.9576
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 820, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9103
# Step 830, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9240
# Step 840, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9318
# Step 850, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9340
# Step 860, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9317
# Step 870, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9380
# Step 880, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9383
# Step 890, Minibatch Loss= 0.0004, Training Accuracy= 0.9796, Test Accuracy= 0.9582
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 900, Minibatch Loss= 0.0002, Training Accuracy= 0.9866, Test Accuracy= 0.9099
# Step 910, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9025
# Step 920, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9178
# Step 930, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9343
# Step 940, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9288
# Step 950, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9337
# Step 960, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9372
# Step 970, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9378
# Step 980, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9396
# Step 990, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9401
# Step 1000, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9401
# Step 1010, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9416
# Step 1020, Minibatch Loss= 0.0005, Training Accuracy= 0.9788, Test Accuracy= 0.9598
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 1030, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.9118
# Step 1040, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9045
# Step 1050, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9153
# Step 1060, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9347
# Step 1070, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9381
# Step 1080, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9384
# Step 1090, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9384
# Step 1100, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9381
# Step 1110, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9379
# Step 1120, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9381
# Step 1130, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9360
# Step 1140, Minibatch Loss= 0.0006, Training Accuracy= 0.9756, Test Accuracy= 0.8851
# Step 1150, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.8923
# Step 1160, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9232
# Step 1170, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9293
# Step 1180, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9319
# Step 1190, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9339
# Step 1200, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9372
# Step 1210, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9370
# Step 1220, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9369
# Step 1230, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9365
# Step 1240, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9289
# Step 1250, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9305
# Step 1260, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9163
# Step 1270, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9308
# Step 1280, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9341
# Step 1290, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9366
# Step 1300, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9364
# Step 1310, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9346
# Step 1320, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9371
# Step 1330, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9407
# Step 1340, Minibatch Loss= 0.0005, Training Accuracy= 0.9783, Test Accuracy= 0.9557
# Step 1350, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.9290
# Step 1360, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.9316
# Step 1370, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9299
# Step 1380, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9313
# Step 1390, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9343
# Step 1400, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9371
# Step 1410, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9359
# Step 1420, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9383
# Step 1430, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9400
# Step 1440, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9481
# Step 1450, Minibatch Loss= 0.0001, Training Accuracy= 0.9891, Test Accuracy= 0.9157
# Step 1460, Minibatch Loss= 0.0003, Training Accuracy= 0.9837, Test Accuracy= 0.8791
# Step 1470, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9313
# Step 1480, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9250
# Step 1490, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9293
# Step 1500, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9354
# Step 1510, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9379
# Step 1520, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9398
# Step 1530, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9424
# Step 1540, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9415
# Step 1550, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9421
# Step 1560, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9379
# Step 1570, Minibatch Loss= 0.0002, Training Accuracy= 0.9843, Test Accuracy= 0.9111
# Step 1580, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.9086
# Step 1590, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9241
# Step 1600, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9312
# Step 1610, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9336
# Step 1620, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9317
# Step 1630, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9334
# Step 1640, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9363
# Step 1650, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9382
# Step 1660, Minibatch Loss= 0.0001, Training Accuracy= 0.9888, Test Accuracy= 0.9462
# Step 1670, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9232
# Step 1680, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9243
# Step 1690, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9303
# Step 1700, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9327
# Step 1710, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9300
# Step 1720, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9324
# Step 1730, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9310
# Step 1740, Minibatch Loss= 0.0002, Training Accuracy= 0.9846, Test Accuracy= 0.9114
# Step 1750, Minibatch Loss= 0.0001, Training Accuracy= 0.9883, Test Accuracy= 0.9340
# Step 1760, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9298
# Step 1770, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9248
# Step 1780, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9255
# Step 1790, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9341
# Step 1800, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9334
# Step 1810, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9314
# Step 1820, Minibatch Loss= 0.0007, Training Accuracy= 0.9735, Test Accuracy= 0.8742
# Step 1830, Minibatch Loss= 0.0003, Training Accuracy= 0.9833, Test Accuracy= 0.8854
# Step 1840, Minibatch Loss= 0.0001, Training Accuracy= 0.9888, Test Accuracy= 0.9255
# Step 1850, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9239
# Step 1860, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9250
# Step 1870, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9317
# Step 1880, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9340
# Step 1890, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9335
# Step 1900, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9364
# Step 1910, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9377
# Step 1920, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9395
# Step 1930, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9431
# Step 1940, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9512
# Step 1950, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9329
# Step 1960, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9297
# Step 1970, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9305
# Step 1980, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9299
# Step 1990, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9351
# Step 2000, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9344

# %%
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    pred00 = session.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = session.run([prediction2], feed_dict={X: test_data, is_training: False})
# Out:
# W0723 17:42:02.512626 140607277242112 deprecation.py:323] From /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred01).reshape(-1,1))
plt.plot(np.array(testY).reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

x=list(range(0,len(pred00[0])))
y1=np.array(pred01).reshape(1,-1)[0]+2*np.std(np.array(pred01).reshape(1,-1))
y2=np.array(pred01).reshape(1,-1)[0]-2*np.std(np.array(pred01).reshape(1,-1))
fig, ax1 = plt.subplots(1, 1, sharex=True)
ax1.plot(np.array(pred01).reshape(1,-1)[0],'--',color='blue',alpha=0.5)
ax1.fill_between(x, y1, y2,color='blue',alpha=0.3)
ax1.plot(x,np.array(testY).reshape(-1,),c='red')
plt.xlabel('Days')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R2',r2_score(testY.reshape(1,-1)[0],np.array(pred01).reshape(1,-1)[0]))
# Out:
# R2 0.5231240789844809

# %%
x_test=X0[-1].reshape(-1,4,1)
prev=[]
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    for i in range(0,21):
        pred02 = session.run([prediction2], feed_dict={X: x_test, is_training: False})[0][0]
        prev.append(pred02)
        #print(pred02)
        x_test=np.concatenate([x_test[0][1:4],[pred02]],axis=0).reshape(-1,4,1)
        #print(x_test)

# %%
limit=12

# %%
plt.plot(np.array(prev)[0:limit].reshape(-1,1))
plt.plot(np.array(testY)[0:limit].reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()
real=np.array(testY)[0:limit].reshape(-1,)[-1]/np.array(testY)[0:limit].reshape(-1,)[0]
prevista=np.array(prev)[0:limit].reshape(-1,1)[-1]/np.array(prev)[0:limit].reshape(-1,1)[0]
print('Variação Real',"%.2f" % real + '%')
print('Variação Prevista',["%.2f" % prevista+'%'])
print('Erro',["%.2f" % float(prevista-real)+'%'])
# Out:
# Variação Real 1.16%
# Variação Prevista ['1.04%']
# Erro ['-0.11%']
