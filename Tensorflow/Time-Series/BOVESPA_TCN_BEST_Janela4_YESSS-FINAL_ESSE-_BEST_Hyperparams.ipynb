# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
#pip install pandas-datareader

stock = 'MGLU3.SA'
source = 'yahoo'

stock2='^BVSP'

# Set date range (Google went public August 19, 2004)
start = datetime.datetime(2005, 8, 19)
end = datetime.datetime(2019, 7, 19)

# Collect Google stock data
goog_df = data.DataReader(stock, source, start, end)
goog_df2 = (data.DataReader(stock2, source, start, end)/(100000))*goog_df.max()

dataset = goog_df['Adj Close']
print(len(dataset))
goog_df['Adj Close'].plot(kind='line', grid=True, title='Adjusted Closes',label=stock)
goog_df2['Adj Close'].plot(color='r',kind='line', grid=True, title='Adjusted Closes',label='IBOV')
plt.legend()
plt.show()
# Out:
# 2037

# %%
import tensorflow as tf
import pandas as pd  
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow_probability as tfp


dataset = np.array(dataset.astype('float32')).reshape(-1,1)

def norm(x):
    return (x-np.min(x))/(np.max(x)-np.min(x))

#dataset=norm(dataset)

look_back=4
np.random.seed(7)
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.99)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))

def create_dataset(dataset, look_back=look_back):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX

trainY = trainY.reshape(len(trainY), 1)
testY = testY.reshape(len(testY), 1)
trainY

X0=trainX
Y0=trainY
# Out:
# 2016 21

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
tfd = tfp.distributions

class TemporalConvNet(tf.layers.Layer):
    def __init__(self, num_channels, kernel_size=2, dropout=0.2,
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalConvNet, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )
        self.layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            out_channels = num_channels[i]
            self.layers.append(
                TemporalBlock(out_channels, kernel_size, strides=1, dilation_rate=dilation_size,
                              dropout=dropout, name="tblock_{}".format(i))
            )
    
    def call(self, inputs, training=True):
        outputs = inputs
        for layer in self.layers:
            outputs = layer(outputs, training=training)
        return outputs

learning_rate = 0.001
display_step = 10
num_input = 1
num_hidden = 35
num_classes = 1

dropout = 0
kernel_size = 8
levels = 6

class CausalConv1D(tf.layers.Conv1D):
    def __init__(self, filters,
               kernel_size,
               strides=1,
               dilation_rate=2,
               activation=None,
               use_bias=True,
               kernel_initializer=None,
               bias_initializer=tf.zeros_initializer(),
               kernel_regularizer=None,
               bias_regularizer=None,
               activity_regularizer=None,
               kernel_constraint=None,
               bias_constraint=None,
               trainable=True,
               name=None,
               **kwargs):
        super(CausalConv1D, self).__init__(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            padding='valid',
            data_format='channels_last',
            dilation_rate=dilation_rate,
            activation=activation,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
            activity_regularizer=activity_regularizer,
            kernel_constraint=kernel_constraint,
            bias_constraint=bias_constraint,
            trainable=trainable,
            name=name, **kwargs
        )
       
    def call(self, inputs):
        padding = (self.kernel_size[0] - 1) * self.dilation_rate[0]
        inputs = tf.pad(inputs, tf.constant([(0, 0,), (1, 0), (0, 0)]) * padding)
        return super(CausalConv1D, self).call(inputs)



class TemporalBlock(tf.layers.Layer):
    def __init__(self, n_outputs, kernel_size, strides, dilation_rate, dropout=0.1, 
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalBlock, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )        
        self.dropout = dropout
        self.n_outputs = n_outputs
        self.conv1 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv1")
        self.conv2 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv2")
        self.down_sample = None

    
    def build(self, input_shape):
        channel_dim = 2
        self.dropout1 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        self.dropout2 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        if input_shape[channel_dim] != self.n_outputs:
            self.down_sample = tf.layers.Dense(self.n_outputs, activation=None)
    
    def call(self, inputs, training=True):
        x = self.conv1(inputs)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout1(x, training=training)
        x = self.conv2(x)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout2(x, training=training)
        #x = tfp.layers.DistributionLambda(make_distribution_fn=lambda t: tfd.Normal(loc=t, scale=1))(x)
        #x = tf.contrib.layers.layer_norm(x)
        #x = tf.layers.dense(inputs=x,units=3)
        if self.down_sample is not None:
          inputs = self.down_sample(inputs)
        return tf.nn.relu(x)



tf.reset_default_graph()
graph = tf.Graph()
with graph.as_default():
    tf.set_random_seed(2)
    
    X = tf.placeholder("float", [None, look_back,1])
    Y = tf.placeholder("float", [None, num_classes])
    is_training = tf.placeholder("bool")
    
    logits = tf.layers.dense(
        TemporalConvNet([num_hidden] * levels, kernel_size, dropout)(
            X, training=is_training),
        num_classes, activation=None, 
        kernel_initializer=tf.glorot_uniform_initializer()
    )
    print(logits)

    mm,_=tf.nn.moments(tf.reshape(tf.nn.relu(logits),[-1,look_back]),axes=[1])
    prediction=tf.nn.relu(logits)
    
    prediction2 = tf.reshape(tf.cast(mm,tf.float32),[-1,1])
    
    loss_op = tf.reduce_mean(tf.losses.mean_squared_error(
        labels=Y,predictions=prediction2))
    
    accuracy=1-tf.sqrt(loss_op)

    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    train_op = optimizer.minimize(loss_op)


    saver = tf.train.Saver()
    print("All parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.global_variables()]))
    print("Trainable parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()]))

def next_batch(num, data, labels):
    idx = np.arange(0 , len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    return np.asarray(data_shuffle).astype(np.float32), np.asarray(labels_shuffle).astype(np.float32)

log_dir = "/home/rubensvectomobile/BOVESPA/"
tb_writer = tf.summary.FileWriter(log_dir, graph)
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.7
best_val_acc = 0.93

training_epochs = 5000
batch_size = X0.shape[0]


X0=X0.reshape(-1,look_back,1)
testX=testX.reshape(-1,look_back,1)
# Out:
# Tensor("dense/BiasAdd:0", shape=(?, 4, 1), dtype=float32)
# All parameters: 328200.0
# Trainable parameters: 109446

# %%
with tf.Session(graph=graph, config=config) as sess:
    init = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
    sess.run(init)
    for step in range(1, training_epochs+1):
        Xt, Yt = next_batch(batch_size, X0, Y0)
        batch_x, batch_y = Xt,Yt
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, is_training: True})
        if step % display_step == 0 or step == 1:
            loss, acc = sess.run([loss_op, accuracy], feed_dict={
                X: batch_x, Y: batch_y, is_training: False})
            test_data = testX
            test_label = testY
            val_acc = sess.run(accuracy, feed_dict={X: test_data, Y: test_label, is_training: False})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.4f}".format(acc) + ", Test Accuracy= " + \
                  "{:.4f}".format(val_acc))
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                save_path = saver.save(sess, "/home/rubensvectomobile/BOVESPA/model.ckpt")
                print("Model saved in path: %s" % save_path)
    pred00 = sess.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = sess.run([prediction2], feed_dict={X: test_data, is_training: False})
# Out:
# Step 1, Minibatch Loss= 0.0468, Training Accuracy= 0.7836, Test Accuracy= 0.1823
# Step 10, Minibatch Loss= 0.0065, Training Accuracy= 0.9195, Test Accuracy= 0.5730
# Step 20, Minibatch Loss= 0.0012, Training Accuracy= 0.9655, Test Accuracy= 0.9036
# Step 30, Minibatch Loss= 0.0003, Training Accuracy= 0.9817, Test Accuracy= 0.8853
# Step 40, Minibatch Loss= 0.0002, Training Accuracy= 0.9843, Test Accuracy= 0.8665
# Step 50, Minibatch Loss= 0.0002, Training Accuracy= 0.9868, Test Accuracy= 0.8925
# Step 60, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.9032
# Step 70, Minibatch Loss= 0.0001, Training Accuracy= 0.9880, Test Accuracy= 0.8921
# Step 80, Minibatch Loss= 0.0001, Training Accuracy= 0.9885, Test Accuracy= 0.9083
# Step 90, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.9027
# Step 100, Minibatch Loss= 0.0005, Training Accuracy= 0.9788, Test Accuracy= 0.8587
# Step 110, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9169
# Step 120, Minibatch Loss= 0.0001, Training Accuracy= 0.9887, Test Accuracy= 0.8935
# Step 130, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.8924
# Step 140, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9247
# Step 150, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9530
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 160, Minibatch Loss= 0.0001, Training Accuracy= 0.9885, Test Accuracy= 0.9257
# Step 170, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9271
# Step 180, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9190
# Step 190, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9300
# Step 200, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9144
# Step 210, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.9208
# Step 220, Minibatch Loss= 0.0001, Training Accuracy= 0.9883, Test Accuracy= 0.8900
# Step 230, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.9190
# Step 240, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9049
# Step 250, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9135
# Step 260, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9272
# Step 270, Minibatch Loss= 0.0016, Training Accuracy= 0.9598, Test Accuracy= 0.8063
# Step 280, Minibatch Loss= 0.0008, Training Accuracy= 0.9717, Test Accuracy= 0.9509
# Step 290, Minibatch Loss= 0.0001, Training Accuracy= 0.9881, Test Accuracy= 0.8796
# Step 300, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.8956
# Step 310, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9069
# Step 320, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9237
# Step 330, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9317
# Step 340, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9260
# Step 350, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9344
# Step 360, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9337
# Step 370, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9352
# Step 380, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9375
# Step 390, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9393
# Step 400, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9397
# Step 410, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9409
# Step 420, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9467
# Step 430, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9550
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 440, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9515
# Step 450, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9417
# Step 460, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9515
# Step 470, Minibatch Loss= 0.0002, Training Accuracy= 0.9871, Test Accuracy= 0.9650
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 480, Minibatch Loss= 0.0001, Training Accuracy= 0.9891, Test Accuracy= 0.9150
# Step 490, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9274
# Step 500, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9550
# Step 510, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9570
# Step 520, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9308
# Step 530, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9443
# Step 540, Minibatch Loss= 0.0012, Training Accuracy= 0.9657, Test Accuracy= 0.8177
# Step 550, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9125
# Step 560, Minibatch Loss= 0.0001, Training Accuracy= 0.9881, Test Accuracy= 0.9002
# Step 570, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9447
# Step 580, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9506
# Step 590, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9523
# Step 600, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9509
# Step 610, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9638
# Step 620, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9699
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 630, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9658
# Step 640, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9530
# Step 650, Minibatch Loss= 0.0002, Training Accuracy= 0.9863, Test Accuracy= 0.9636
# Step 660, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.8948
# Step 670, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9357
# Step 680, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9349
# Step 690, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9431
# Step 700, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9527
# Step 710, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9523
# Step 720, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9582
# Step 730, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9689
# Step 740, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9418
# Step 750, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9579
# Step 760, Minibatch Loss= 0.0002, Training Accuracy= 0.9864, Test Accuracy= 0.9795
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 770, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9663
# Step 780, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9655
# Step 790, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9627
# Step 800, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9766
# Step 810, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9358
# Step 820, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9640
# Step 830, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.9305
# Step 840, Minibatch Loss= 0.0001, Training Accuracy= 0.9884, Test Accuracy= 0.9789
# Step 850, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9573
# Step 860, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9445
# Step 870, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9518
# Step 880, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9098
# Step 890, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9449
# Step 900, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9752
# Step 910, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9377
# Step 920, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9510
# Step 930, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9763
# Step 940, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9585
# Step 950, Minibatch Loss= 0.0001, Training Accuracy= 0.9885, Test Accuracy= 0.9294
# Step 960, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9745
# Step 970, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9335
# Step 980, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.9772
# Step 990, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9553
# Step 1000, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9409
# Step 1010, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9672
# Step 1020, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9783
# Step 1030, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9430
# Step 1040, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9759
# Step 1050, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9736
# Step 1060, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9386
# Step 1070, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9690
# Step 1080, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9682
# Step 1090, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9563
# Step 1100, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9513
# Step 1110, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9677
# Step 1120, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9479
# Step 1130, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9598
# Step 1140, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9677
# Step 1150, Minibatch Loss= 0.0003, Training Accuracy= 0.9814, Test Accuracy= 0.9800
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 1160, Minibatch Loss= 0.0004, Training Accuracy= 0.9801, Test Accuracy= 0.8586
# Step 1170, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9064
# Step 1180, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9442
# Step 1190, Minibatch Loss= 0.0001, Training Accuracy= 0.9880, Test Accuracy= 0.9407
# Step 1200, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9144
# Step 1210, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9254
# Step 1220, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9390
# Step 1230, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9432
# Step 1240, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9442
# Step 1250, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9522
# Step 1260, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9530
# Step 1270, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9555
# Step 1280, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9573
# Step 1290, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9555
# Step 1300, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9360
# Step 1310, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9622
# Step 1320, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9600
# Step 1330, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9611
# Step 1340, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9496
# Step 1350, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9527
# Step 1360, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9387
# Step 1370, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9546
# Step 1380, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9534
# Step 1390, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9682
# Step 1400, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9646
# Step 1410, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9652
# Step 1420, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9494
# Step 1430, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9566
# Step 1440, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9400
# Step 1450, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9575
# Step 1460, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9612
# Step 1470, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9430
# Step 1480, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9632
# Step 1490, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9568
# Step 1500, Minibatch Loss= 0.0001, Training Accuracy= 0.9878, Test Accuracy= 0.9248
# Step 1510, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9681
# Step 1520, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9514
# Step 1530, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9733
# Step 1540, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9527
# Step 1550, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9450
# Step 1560, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9658
# Step 1570, Minibatch Loss= 0.0003, Training Accuracy= 0.9818, Test Accuracy= 0.9772
# Step 1580, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.9649
# Step 1590, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9382
# Step 1600, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9481
# Step 1610, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9663
# Step 1620, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9535
# Step 1630, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9513
# Step 1640, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9648
# Step 1650, Minibatch Loss= 0.0002, Training Accuracy= 0.9876, Test Accuracy= 0.9765
# Step 1660, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9557
# Step 1670, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9376
# Step 1680, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9619
# Step 1690, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9491
# Step 1700, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9539
# Step 1710, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9581
# Step 1720, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.8941
# Step 1730, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9118
# Step 1740, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9495
# Step 1750, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9483
# Step 1760, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9368
# Step 1770, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9461
# Step 1780, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9623
# Step 1790, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9613
# Step 1800, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9651
# Step 1810, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9616
# Step 1820, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9490
# Step 1830, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9614
# Step 1840, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9475
# Step 1850, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9325
# Step 1860, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9676
# Step 1870, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9289
# Step 1880, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9709
# Step 1890, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9403
# Step 1900, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9574
# Step 1910, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9736
# Step 1920, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9286
# Step 1930, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9706
# Step 1940, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9361
# Step 1950, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9653
# Step 1960, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9595
# Step 1970, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9298
# Step 1980, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9683
# Step 1990, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9449
# Step 2000, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9482
# Step 2010, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9625
# Step 2020, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9299
# Step 2030, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9613
# Step 2040, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9457
# Step 2050, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9579
# Step 2060, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9650
# Step 2070, Minibatch Loss= 0.0004, Training Accuracy= 0.9809, Test Accuracy= 0.9695
# Step 2080, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.8561
# Step 2090, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9428
# Step 2100, Minibatch Loss= 0.0004, Training Accuracy= 0.9795, Test Accuracy= 0.9803
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 2110, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.9441
# Step 2120, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9409
# Step 2130, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.9209
# Step 2140, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9519
# Step 2150, Minibatch Loss= 0.0002, Training Accuracy= 0.9873, Test Accuracy= 0.9714
# Step 2160, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9676
# Step 2170, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9316
# Step 2180, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9498
# Step 2190, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9698
# Step 2200, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9674
# Step 2210, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9583
# Step 2220, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9746
# Step 2230, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9703
# Step 2240, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9683
# Step 2250, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9692
# Step 2260, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9696
# Step 2270, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9699
# Step 2280, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9702
# Step 2290, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9701
# Step 2300, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9707
# Step 2310, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9715
# Step 2320, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9710
# Step 2330, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9698
# Step 2340, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9729
# Step 2350, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9714
# Step 2360, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9686
# Step 2370, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9715
# Step 2380, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9763
# Step 2390, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9662
# Step 2400, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9630
# Step 2410, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9756
# Step 2420, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9745
# Step 2430, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9591
# Step 2440, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9722
# Step 2450, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9801
# Step 2460, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9520
# Step 2470, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9787
# Step 2480, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9572
# Step 2490, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9734
# Step 2500, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9794
# Step 2510, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9595
# Step 2520, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9800
# Step 2530, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9575
# Step 2540, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9780
# Step 2550, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9558
# Step 2560, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9765
# Step 2570, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9489
# Step 2580, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9781
# Step 2590, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9554
# Step 2600, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9622
# Step 2610, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9784
# Step 2620, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9459
# Step 2630, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9785
# Step 2640, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9484
# Step 2650, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9761
# Step 2660, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9452
# Step 2670, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9765
# Step 2680, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9449
# Step 2690, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9761
# Step 2700, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9461
# Step 2710, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9748
# Step 2720, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9506
# Step 2730, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9697
# Step 2740, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9480
# Step 2750, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9617
# Step 2760, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9729
# Step 2770, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9529
# Step 2780, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9560
# Step 2790, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9637
# Step 2800, Minibatch Loss= 0.0002, Training Accuracy= 0.9871, Test Accuracy= 0.9762
# Step 2810, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9648
# Step 2820, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9452
# Step 2830, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9640
# Step 2840, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9455
# Step 2850, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9560
# Step 2860, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9479
# Step 2870, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9479
# Step 2880, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9434
# Step 2890, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9706
# Step 2900, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9481
# Step 2910, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9619
# Step 2920, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9568
# Step 2930, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9520
# Step 2940, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9620
# Step 2950, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9357
# Step 2960, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9651
# Step 2970, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9319
# Step 2980, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9613
# Step 2990, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9398
# Step 3000, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9624
# Step 3010, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9561
# Step 3020, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9356
# Step 3030, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9523
# Step 3040, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9646
# Step 3050, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9415
# Step 3060, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9678
# Step 3070, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9230
# Step 3080, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9405
# Step 3090, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9552
# Step 3100, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9378
# Step 3110, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9481
# Step 3120, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9614
# Step 3130, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9299
# Step 3140, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9612
# Step 3150, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9386
# Step 3160, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9449
# Step 3170, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9621
# Step 3180, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9354
# Step 3190, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9600
# Step 3200, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9417
# Step 3210, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9549
# Step 3220, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9461
# Step 3230, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9303
# Step 3240, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9637
# Step 3250, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9437
# Step 3260, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9224
# Step 3270, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9540
# Step 3280, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9209
# Step 3290, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9549
# Step 3300, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9382
# Step 3310, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9666
# Step 3320, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9175
# Step 3330, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9564
# Step 3340, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9467
# Step 3350, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.9677
# Step 3360, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9537
# Step 3370, Minibatch Loss= 0.0001, Training Accuracy= 0.9892, Test Accuracy= 0.9207
# Step 3380, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9404
# Step 3390, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9573
# Step 3400, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9457
# Step 3410, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9301
# Step 3420, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9612
# Step 3430, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9391
# Step 3440, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9504
# Step 3450, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9664
# Step 3460, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9215
# Step 3470, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9641
# Step 3480, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9438
# Step 3490, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9587
# Step 3500, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9367
# Step 3510, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9623
# Step 3520, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9422
# Step 3530, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9401
# Step 3540, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9629
# Step 3550, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9218
# Step 3560, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9700
# Step 3570, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9342
# Step 3580, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9560
# Step 3590, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9334
# Step 3600, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9514
# Step 3610, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9637
# Step 3620, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9316
# Step 3630, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9649
# Step 3640, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9265
# Step 3650, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9626
# Step 3660, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9374
# Step 3670, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9534
# Step 3680, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9371
# Step 3690, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9592
# Step 3700, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9512
# Step 3710, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9558
# Step 3720, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9527
# Step 3730, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9303
# Step 3740, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9634
# Step 3750, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9302
# Step 3760, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9604
# Step 3770, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9429
# Step 3780, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9351
# Step 3790, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9489
# Step 3800, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9243
# Step 3810, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9423
# Step 3820, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9450
# Step 3830, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9577
# Step 3840, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9350
# Step 3850, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9597
# Step 3860, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9501
# Step 3870, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9337
# Step 3880, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9601
# Step 3890, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9318
# Step 3900, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9643
# Step 3910, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9136
# Step 3920, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9504
# Step 3930, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9408
# Step 3940, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9496
# Step 3950, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9590
# Step 3960, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9363
# Step 3970, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9553
# Step 3980, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9367
# Step 3990, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9521
# Step 4000, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9379
# Step 4010, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9498
# Step 4020, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9421
# Step 4030, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9461
# Step 4040, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9501
# Step 4050, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9306
# Step 4060, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9567
# Step 4070, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9454
# Step 4080, Minibatch Loss= 0.0001, Training Accuracy= 0.9885, Test Accuracy= 0.9093
# Step 4090, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9396
# Step 4100, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9508
# Step 4110, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9352
# Step 4120, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9507
# Step 4130, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9441
# Step 4140, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9387
# Step 4150, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9420
# Step 4160, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9106
# Step 4170, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9380
# Step 4180, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9327
# Step 4190, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9310
# Step 4200, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9544
# Step 4210, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9378
# Step 4220, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9523
# Step 4230, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9461
# Step 4240, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9314
# Step 4250, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9416
# Step 4260, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9389
# Step 4270, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9421
# Step 4280, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9448
# Step 4290, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9476
# Step 4300, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9326
# Step 4310, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9515
# Step 4320, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9149
# Step 4330, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9520
# Step 4340, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9235
# Step 4350, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9455
# Step 4360, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9325
# Step 4370, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9485
# Step 4380, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9173
# Step 4390, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9460
# Step 4400, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9127
# Step 4410, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9421
# Step 4420, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9310
# Step 4430, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9405
# Step 4440, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9412
# Step 4450, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9431
# Step 4460, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9183
# Step 4470, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9161
# Step 4480, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9402
# Step 4490, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9472
# Step 4500, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9047
# Step 4510, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9281
# Step 4520, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9232
# Step 4530, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9268
# Step 4540, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9175
# Step 4550, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9211
# Step 4560, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9238
# Step 4570, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9273
# Step 4580, Minibatch Loss= 0.0000, Training Accuracy= 0.9934, Test Accuracy= 0.9288
# Step 4590, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9135
# Step 4600, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9278
# Step 4610, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.9067
# Step 4620, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9314
# Step 4630, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.9076
# Step 4640, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9228
# Step 4650, Minibatch Loss= 0.0000, Training Accuracy= 0.9934, Test Accuracy= 0.9240
# Step 4660, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9162
# Step 4670, Minibatch Loss= 0.0000, Training Accuracy= 0.9935, Test Accuracy= 0.9242
# Step 4680, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9257
# Step 4690, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9115
# Step 4700, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9263
# Step 4710, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9156
# Step 4720, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9262
# Step 4730, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9177
# Step 4740, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9114
# Step 4750, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9173
# Step 4760, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9098
# Step 4770, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9180
# Step 4780, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9138
# Step 4790, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9222
# Step 4800, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9036
# Step 4810, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9054
# Step 4820, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9070
# Step 4830, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9139
# Step 4840, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9046
# Step 4850, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9146
# Step 4860, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9124
# Step 4870, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9151
# Step 4880, Minibatch Loss= 0.0000, Training Accuracy= 0.9934, Test Accuracy= 0.9160
# Step 4890, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9066
# Step 4900, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9152
# Step 4910, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9021
# Step 4920, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9256
# Step 4930, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.8815
# Step 4940, Minibatch Loss= 0.0281, Training Accuracy= 0.8323, Test Accuracy= 0.3067
# Step 4950, Minibatch Loss= 0.0095, Training Accuracy= 0.9027, Test Accuracy= 0.6777
# Step 4960, Minibatch Loss= 0.0057, Training Accuracy= 0.9246, Test Accuracy= 0.5669
# Step 4970, Minibatch Loss= 0.0016, Training Accuracy= 0.9594, Test Accuracy= 0.7957
# Step 4980, Minibatch Loss= 0.0011, Training Accuracy= 0.9672, Test Accuracy= 0.8724
# Step 4990, Minibatch Loss= 0.0006, Training Accuracy= 0.9762, Test Accuracy= 0.8452
# Step 5000, Minibatch Loss= 0.0004, Training Accuracy= 0.9811, Test Accuracy= 0.8378

# %%
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    pred00 = session.run([prediction], feed_dict={X: testX, is_training: False})
    pred01 = session.run([prediction2], feed_dict={X: testX, is_training: False})
    pred02 = session.run([prediction2], feed_dict={X: trainX.reshape(-1,look_back,1), is_training: False})

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred02).reshape(-1,1)[-200:])
plt.plot(np.array(trainX).reshape(-1,)[-200:],c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred01).reshape(-1,1))
plt.plot(np.array(testY).reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

x=list(range(0,len(pred00[0])))
y1=np.array(pred01).reshape(1,-1)[0]+2*np.std(np.array(pred01).reshape(1,-1))
y2=np.array(pred01).reshape(1,-1)[0]-2*np.std(np.array(pred01).reshape(1,-1))
fig, ax1 = plt.subplots(1, 1, sharex=True)
ax1.plot(np.array(pred01).reshape(1,-1)[0],'--',color='blue',alpha=0.5)
ax1.fill_between(x, y1, y2,color='blue',alpha=0.3)
ax1.plot(x,np.array(testY).reshape(-1,),c='red')
plt.xlabel('Days')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R2',r2_score(testY.reshape(1,-1)[0],np.array(pred01).reshape(1,-1)[0]))
# Out:
# R2 0.8367379619681445

# %%
x_test=testX[0].reshape(-1,look_back,1)
prev=[]
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    for i in range(0,21):
        pred02 = session.run([prediction2], feed_dict={X: x_test, is_training: False})[0][0]
        prev.append(pred02)
        #print(pred02)
        x_test=np.concatenate([x_test[0][1:look_back],[pred02]],axis=0).reshape(-1,look_back,1)
        #print(x_test)

# %%
limit=17
len(testY)
# Out:
# 17

# %%
np.array(testY)[0:limit].reshape(-1,)[-1]
# Out:
# 0.9636283

# %%
plt.plot(np.array(prev)[0:limit].reshape(-1,1))
plt.plot(np.array(testY)[0:limit].reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()
real=(np.array(testY)[0:limit].reshape(-1,)[-1]/np.array(testY)[0:limit].reshape(-1,)[0]-1)*100
prevista=(np.array(prev)[0:limit].reshape(-1,1)[-1]/np.array(prev)[0:limit].reshape(-1,1)[0]-1)*100
print('Variação Real',"%.2f" % real + '%')
print('Variação Prevista',["%.2f" % prevista+'%'])
print('Erro',["%.2f" % float((prevista-real))+'%'])
# Out:
# Variação Real 14.26%
# Variação Prevista ['6.82%']
# Erro ['-7.44%']
