# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
#pip install pandas-datareader

stock = 'MGLU3.SA'
source = 'yahoo'

# Set date range (Google went public August 19, 2004)
start = datetime.datetime(2005, 8, 19)
end = datetime.datetime(2019, 7, 19)

# Collect Google stock data
goog_df = data.DataReader(stock, source, start, end)

dataset = goog_df['Adj Close']
print(len(dataset))
goog_df['Adj Close'].plot(kind='line', grid=True, title='GOOG Adjusted Closes, IPO through 2016')
# Out:
# 2037

# %%
import tensorflow as tf
import pandas as pd  
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow_probability as tfp


dataset = np.array(dataset.astype('float32')).reshape(-1,1)

def norm(x):
    return (x-np.min(x))/(np.max(x)-np.min(x))

#dataset=norm(dataset)

look_back=4
np.random.seed(7)
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.99)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))

def create_dataset(dataset, look_back=look_back):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX

trainY = trainY.reshape(len(trainY), 1)
testY = testY.reshape(len(testY), 1)
trainY

X0=trainX
Y0=trainY
# Out:
# 2016 21

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
tfd = tfp.distributions

class TemporalConvNet(tf.layers.Layer):
    def __init__(self, num_channels, kernel_size=2, dropout=0.2,
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalConvNet, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )
        self.layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            out_channels = num_channels[i]
            self.layers.append(
                TemporalBlock(out_channels, kernel_size, strides=1, dilation_rate=dilation_size,
                              dropout=dropout, name="tblock_{}".format(i))
            )
    
    def call(self, inputs, training=True):
        outputs = inputs
        for layer in self.layers:
            outputs = layer(outputs, training=training)
        return outputs

learning_rate = 0.001
display_step = 10
num_input = 1
num_hidden = 35
num_classes = 1

dropout = 0
kernel_size = 8
levels = 6

class CausalConv1D(tf.layers.Conv1D):
    def __init__(self, filters,
               kernel_size,
               strides=1,
               dilation_rate=1,
               activation=None,
               use_bias=True,
               kernel_initializer=None,
               bias_initializer=tf.zeros_initializer(),
               kernel_regularizer=None,
               bias_regularizer=None,
               activity_regularizer=None,
               kernel_constraint=None,
               bias_constraint=None,
               trainable=True,
               name=None,
               **kwargs):
        super(CausalConv1D, self).__init__(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            padding='valid',
            data_format='channels_last',
            dilation_rate=dilation_rate,
            activation=activation,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
            activity_regularizer=activity_regularizer,
            kernel_constraint=kernel_constraint,
            bias_constraint=bias_constraint,
            trainable=trainable,
            name=name, **kwargs
        )
       
    def call(self, inputs):
        padding = (self.kernel_size[0] - 1) * self.dilation_rate[0]
        inputs = tf.pad(inputs, tf.constant([(0, 0,), (1, 0), (0, 0)]) * padding)
        return super(CausalConv1D, self).call(inputs)



class TemporalBlock(tf.layers.Layer):
    def __init__(self, n_outputs, kernel_size, strides, dilation_rate, dropout=0.1, 
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalBlock, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )        
        self.dropout = dropout
        self.n_outputs = n_outputs
        self.conv1 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv1")
        self.conv2 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv2")
        self.down_sample = None

    
    def build(self, input_shape):
        channel_dim = 2
        self.dropout1 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        self.dropout2 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        if input_shape[channel_dim] != self.n_outputs:
            self.down_sample = tf.layers.Dense(self.n_outputs, activation=None)
    
    def call(self, inputs, training=True):
        x = self.conv1(inputs)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout1(x, training=training)
        x = self.conv2(x)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout2(x, training=training)
        #x = tfp.layers.DistributionLambda(make_distribution_fn=lambda t: tfd.Normal(loc=t, scale=1))(x)
        #x = tf.contrib.layers.layer_norm(x)
        #x = tf.layers.dense(inputs=x,units=3)
        if self.down_sample is not None:
          inputs = self.down_sample(inputs)
        return tf.nn.relu(x)



tf.reset_default_graph()
graph = tf.Graph()
with graph.as_default():
    tf.set_random_seed(2)
    
    X = tf.placeholder("float", [None, look_back,1])
    Y = tf.placeholder("float", [None, num_classes])
    is_training = tf.placeholder("bool")
    
    logits = tf.layers.dense(
        TemporalConvNet([num_hidden] * levels, kernel_size, dropout)(
            X, training=is_training),
        num_classes, activation=None, 
        kernel_initializer=tf.glorot_uniform_initializer()
    )
    print(logits)

    mm,_=tf.nn.moments(tf.reshape(tf.nn.relu(logits),[-1,look_back]),axes=[1])
    prediction=tf.nn.relu(logits)
    
    prediction2 = tf.reshape(tf.cast(mm,tf.float32),[-1,1])
    
    loss_op = tf.reduce_mean(tf.losses.mean_squared_error(
        labels=Y,predictions=prediction2))
    
    accuracy=1-tf.sqrt(loss_op)

    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    train_op = optimizer.minimize(loss_op)


    saver = tf.train.Saver()
    print("All parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.global_variables()]))
    print("Trainable parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()]))

def next_batch(num, data, labels):
    idx = np.arange(0 , len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    return np.asarray(data_shuffle).astype(np.float32), np.asarray(labels_shuffle).astype(np.float32)

log_dir = "/home/rubensvectomobile/BOVESPA/"
tb_writer = tf.summary.FileWriter(log_dir, graph)
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.7
best_val_acc = 0.93

training_epochs = 10000
batch_size = X0.shape[0]


X0=X0.reshape(-1,look_back,1)
testX=testX.reshape(-1,look_back,1)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0726 11:49:02.965204 139824759461632 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0726 11:49:03.076892 139824759461632 deprecation.py:506] From /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0726 11:49:04.716490 139824759461632 deprecation.py:323] From <ipython-input-5-7aed8fb23f1d>:140: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0726 11:49:04.768301 139824759461632 deprecation.py:323] From /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Tensor("dense/BiasAdd:0", shape=(?, 4, 1), dtype=float32)
# All parameters: 328200.0
# Trainable parameters: 109446

# %%
with tf.Session(graph=graph, config=config) as sess:
    init = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
    sess.run(init)
    for step in range(1, training_epochs+1):
        Xt, Yt = next_batch(batch_size, X0, Y0)
        batch_x, batch_y = Xt,Yt
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, is_training: True})
        if step % display_step == 0 or step == 1:
            loss, acc = sess.run([loss_op, accuracy], feed_dict={
                X: batch_x, Y: batch_y, is_training: False})
            test_data = testX
            test_label = testY
            val_acc = sess.run(accuracy, feed_dict={X: test_data, Y: test_label, is_training: False})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.4f}".format(acc) + ", Test Accuracy= " + \
                  "{:.4f}".format(val_acc))
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                save_path = saver.save(sess, "/home/rubensvectomobile/BOVESPA/model.ckpt")
                print("Model saved in path: %s" % save_path)
    pred00 = sess.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = sess.run([prediction2], feed_dict={X: test_data, is_training: False})
# Out:
# Step 1, Minibatch Loss= 0.0468, Training Accuracy= 0.7836, Test Accuracy= 0.1823
# Step 10, Minibatch Loss= 0.0048, Training Accuracy= 0.9308, Test Accuracy= 0.6251
# Step 20, Minibatch Loss= 0.0007, Training Accuracy= 0.9731, Test Accuracy= 0.8341
# Step 30, Minibatch Loss= 0.0006, Training Accuracy= 0.9747, Test Accuracy= 0.8103
# Step 40, Minibatch Loss= 0.0003, Training Accuracy= 0.9836, Test Accuracy= 0.8911
# Step 50, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.8817
# Step 60, Minibatch Loss= 0.0002, Training Accuracy= 0.9864, Test Accuracy= 0.8841
# Step 70, Minibatch Loss= 0.0002, Training Accuracy= 0.9870, Test Accuracy= 0.8881
# Step 80, Minibatch Loss= 0.0001, Training Accuracy= 0.9878, Test Accuracy= 0.8975
# Step 90, Minibatch Loss= 0.0001, Training Accuracy= 0.9883, Test Accuracy= 0.8989
# Step 100, Minibatch Loss= 0.0001, Training Accuracy= 0.9888, Test Accuracy= 0.9013
# Step 110, Minibatch Loss= 0.0001, Training Accuracy= 0.9891, Test Accuracy= 0.9067
# Step 120, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.9094
# Step 130, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9105
# Step 140, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9068
# Step 150, Minibatch Loss= 0.0016, Training Accuracy= 0.9602, Test Accuracy= 0.9580
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 160, Minibatch Loss= 0.0003, Training Accuracy= 0.9842, Test Accuracy= 0.8335
# Step 170, Minibatch Loss= 0.0001, Training Accuracy= 0.9880, Test Accuracy= 0.8934
# Step 180, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.8978
# Step 190, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9051
# Step 200, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9342
# Step 210, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9402
# Step 220, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9435
# Step 230, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9399
# Step 240, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9422
# Step 250, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9436
# Step 260, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9471
# Step 270, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9487
# Step 280, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9505
# Step 290, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9505
# Step 300, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9494
# Step 310, Minibatch Loss= 0.0001, Training Accuracy= 0.9880, Test Accuracy= 0.9250
# Step 320, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9434
# Step 330, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9523
# Step 340, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9361
# Step 350, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9567
# Step 360, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9589
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 370, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9162
# Step 380, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9107
# Step 390, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9431
# Step 400, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9493
# Step 410, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9409
# Step 420, Minibatch Loss= 0.0002, Training Accuracy= 0.9876, Test Accuracy= 0.9215
# Step 430, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9558
# Step 440, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9520
# Step 450, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.9667
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 460, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9504
# Step 470, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9494
# Step 480, Minibatch Loss= 0.0002, Training Accuracy= 0.9863, Test Accuracy= 0.8983
# Step 490, Minibatch Loss= 0.0001, Training Accuracy= 0.9887, Test Accuracy= 0.9354
# Step 500, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9191
# Step 510, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9207
# Step 520, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9328
# Step 530, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9462
# Step 540, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9565
# Step 550, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9432
# Step 560, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9503
# Step 570, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9266
# Step 580, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9576
# Step 590, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9477
# Step 600, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9341
# Step 610, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9097
# Step 620, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9339
# Step 630, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9308
# Step 640, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9245
# Step 650, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9329
# Step 660, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9453
# Step 670, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9414
# Step 680, Minibatch Loss= 0.0002, Training Accuracy= 0.9863, Test Accuracy= 0.9106
# Step 690, Minibatch Loss= 0.0002, Training Accuracy= 0.9872, Test Accuracy= 0.9560
# Step 700, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9329
# Step 710, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9355
# Step 720, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9485
# Step 730, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9385
# Step 740, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9547
# Step 750, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9637
# Step 760, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9305
# Step 770, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9479
# Step 780, Minibatch Loss= 0.0002, Training Accuracy= 0.9876, Test Accuracy= 0.9766
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 790, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.8959
# Step 800, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.9282
# Step 810, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9082
# Step 820, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9270
# Step 830, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9366
# Step 840, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9503
# Step 850, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9412
# Step 860, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9408
# Step 870, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9610
# Step 880, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9506
# Step 890, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9388
# Step 900, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9507
# Step 910, Minibatch Loss= 0.0003, Training Accuracy= 0.9841, Test Accuracy= 0.8834
# Step 920, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9127
# Step 930, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9249
# Step 940, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9295
# Step 950, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9269
# Step 960, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9408
# Step 970, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9339
# Step 980, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.9101
# Step 990, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9515
# Step 1000, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9246
# Step 1010, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9486
# Step 1020, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9398
# Step 1030, Minibatch Loss= 0.0002, Training Accuracy= 0.9864, Test Accuracy= 0.9085
# Step 1040, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9519
# Step 1050, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9263
# Step 1060, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9192
# Step 1070, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9257
# Step 1080, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9400
# Step 1090, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9401
# Step 1100, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9149
# Step 1110, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.9490
# Step 1120, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9218
# Step 1130, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9192
# Step 1140, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9261
# Step 1150, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9380
# Step 1160, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9419
# Step 1170, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9491
# Step 1180, Minibatch Loss= 0.0002, Training Accuracy= 0.9873, Test Accuracy= 0.9692
# Step 1190, Minibatch Loss= 0.0001, Training Accuracy= 0.9879, Test Accuracy= 0.9061
# Step 1200, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9192
# Step 1210, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9361
# Step 1220, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9453
# Step 1230, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9419
# Step 1240, Minibatch Loss= 0.0001, Training Accuracy= 0.9892, Test Accuracy= 0.9244
# Step 1250, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.9583
# Step 1260, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9404
# Step 1270, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9418
# Step 1280, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9342
# Step 1290, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9402
# Step 1300, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9450
# Step 1310, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9494
# Step 1320, Minibatch Loss= 0.0003, Training Accuracy= 0.9837, Test Accuracy= 0.9044
# Step 1330, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9174
# Step 1340, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9049
# Step 1350, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9451
# Step 1360, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9447
# Step 1370, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9557
# Step 1380, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9460
# Step 1390, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9561
# Step 1400, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9658
# Step 1410, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9473
# Step 1420, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9558
# Step 1430, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9483
# Step 1440, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.9184
# Step 1450, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9549
# Step 1460, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9472
# Step 1470, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9605
# Step 1480, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9575
# Step 1490, Minibatch Loss= 0.0002, Training Accuracy= 0.9873, Test Accuracy= 0.9773
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 1500, Minibatch Loss= 0.0001, Training Accuracy= 0.9892, Test Accuracy= 0.8980
# Step 1510, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9325
# Step 1520, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9426
# Step 1530, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9526
# Step 1540, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9449
# Step 1550, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9617
# Step 1560, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9668
# Step 1570, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9639
# Step 1580, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9530
# Step 1590, Minibatch Loss= 0.0001, Training Accuracy= 0.9878, Test Accuracy= 0.9228
# Step 1600, Minibatch Loss= 0.0001, Training Accuracy= 0.9892, Test Accuracy= 0.9588
# Step 1610, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9595
# Step 1620, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9333
# Step 1630, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9437
# Step 1640, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9577
# Step 1650, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9730
# Step 1660, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9410
# Step 1670, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9453
# Step 1680, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9709
# Step 1690, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9138
# Step 1700, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9348
# Step 1710, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9634
# Step 1720, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9437
# Step 1730, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9614
# Step 1740, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9527
# Step 1750, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.9119
# Step 1760, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9403
# Step 1770, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9503
# Step 1780, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9585
# Step 1790, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9326
# Step 1800, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9659
# Step 1810, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9563
# Step 1820, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9321
# Step 1830, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9431
# Step 1840, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9632
# Step 1850, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9429
# Step 1860, Minibatch Loss= 0.0002, Training Accuracy= 0.9870, Test Accuracy= 0.9072
# Step 1870, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9298
# Step 1880, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9602
# Step 1890, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9380
# Step 1900, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9461
# Step 1910, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9362
# Step 1920, Minibatch Loss= 0.0001, Training Accuracy= 0.9884, Test Accuracy= 0.9518
# Step 1930, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9434
# Step 1940, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9418
# Step 1950, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9363
# Step 1960, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9605
# Step 1970, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9520
# Step 1980, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.9250
# Step 1990, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9622
# Step 2000, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9334
# Step 2010, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9603
# Step 2020, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.9723
# Step 2030, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9529
# Step 2040, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9310
# Step 2050, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9641
# Step 2060, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9402
# Step 2070, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9411
# Step 2080, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9515
# Step 2090, Minibatch Loss= 0.0001, Training Accuracy= 0.9878, Test Accuracy= 0.9173
# Step 2100, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9568
# Step 2110, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9437
# Step 2120, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9729
# Step 2130, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9312
# Step 2140, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9648
# Step 2150, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9382
# Step 2160, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9565
# Step 2170, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9353
# Step 2180, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9668
# Step 2190, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9565
# Step 2200, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9531
# Step 2210, Minibatch Loss= 0.0001, Training Accuracy= 0.9884, Test Accuracy= 0.8962
# Step 2220, Minibatch Loss= 0.0002, Training Accuracy= 0.9870, Test Accuracy= 0.9208
# Step 2230, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.9013
# Step 2240, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9478
# Step 2250, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9466
# Step 2260, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9653
# Step 2270, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9665
# Step 2280, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9651
# Step 2290, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9581
# Step 2300, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9487
# Step 2310, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9749
# Step 2320, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9494
# Step 2330, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9491
# Step 2340, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9708
# Step 2350, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9532
# Step 2360, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9687
# Step 2370, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9455
# Step 2380, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9577
# Step 2390, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9753
# Step 2400, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9415
# Step 2410, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9695
# Step 2420, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9441
# Step 2430, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9543
# Step 2440, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9306
# Step 2450, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9629
# Step 2460, Minibatch Loss= 0.0002, Training Accuracy= 0.9870, Test Accuracy= 0.9178
# Step 2470, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9274
# Step 2480, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9502
# Step 2490, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9647
# Step 2500, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9627
# Step 2510, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9494
# Step 2520, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9530
# Step 2530, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9702
# Step 2540, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9374
# Step 2550, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9665
# Step 2560, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9409
# Step 2570, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9469
# Step 2580, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9666
# Step 2590, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9436
# Step 2600, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9552
# Step 2610, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9735
# Step 2620, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9321
# Step 2630, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9755
# Step 2640, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9123
# Step 2650, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9380
# Step 2660, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9609
# Step 2670, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9531
# Step 2680, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9272
# Step 2690, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9484
# Step 2700, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9326
# Step 2710, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9592
# Step 2720, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.9179
# Step 2730, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9430
# Step 2740, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9705
# Step 2750, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9364
# Step 2760, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9680
# Step 2770, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9482
# Step 2780, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9613
# Step 2790, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9717
# Step 2800, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9616
# Step 2810, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9559
# Step 2820, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9676
# Step 2830, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9513
# Step 2840, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9709
# Step 2850, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9523
# Step 2860, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9509
# Step 2870, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9374
# Step 2880, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9610
# Step 2890, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9690
# Step 2900, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9677
# Step 2910, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9462
# Step 2920, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9651
# Step 2930, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.9728
# Step 2940, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9654
# Step 2950, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9491
# Step 2960, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9452
# Step 2970, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9577
# Step 2980, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9502
# Step 2990, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9459
# Step 3000, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9573
# Step 3010, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9342
# Step 3020, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9628
# Step 3030, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9453
# Step 3040, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9502
# Step 3050, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9429
# Step 3060, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9621
# Step 3070, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9662
# Step 3080, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9371
# Step 3090, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9689
# Step 3100, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9488
# Step 3110, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9281
# Step 3120, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9683
# Step 3130, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9576
# Step 3140, Minibatch Loss= 0.0001, Training Accuracy= 0.9878, Test Accuracy= 0.9194
# Step 3150, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9537
# Step 3160, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9716
# Step 3170, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9400
# Step 3180, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9629
# Step 3190, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.9806
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 3200, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9432
# Step 3210, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9637
# Step 3220, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9618
# Step 3230, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9658
# Step 3240, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9477
# Step 3250, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9757
# Step 3260, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9300
# Step 3270, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9754
# Step 3280, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9362
# Step 3290, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9560
# Step 3300, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9744
# Step 3310, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9184
# Step 3320, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9647
# Step 3330, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9521
# Step 3340, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9782
# Step 3350, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9274
# Step 3360, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9752
# Step 3370, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9369
# Step 3380, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9572
# Step 3390, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.9817
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 3400, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9254
# Step 3410, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9471
# Step 3420, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9371
# Step 3430, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9493
# Step 3440, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9695
# Step 3450, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9571
# Step 3460, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9384
# Step 3470, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9611
# Step 3480, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9711
# Step 3490, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9399
# Step 3500, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9539
# Step 3510, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9796
# Step 3520, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9275
# Step 3530, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9742
# Step 3540, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9433
# Step 3550, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9405
# Step 3560, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9728
# Step 3570, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9556
# Step 3580, Minibatch Loss= 0.0002, Training Accuracy= 0.9876, Test Accuracy= 0.9143
# Step 3590, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9535
# Step 3600, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9554
# Step 3610, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9705
# Step 3620, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9639
# Step 3630, Minibatch Loss= 0.0001, Training Accuracy= 0.9885, Test Accuracy= 0.9814
# Step 3640, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9307
# Step 3650, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9354
# Step 3660, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9738
# Step 3670, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9475
# Step 3680, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9475
# Step 3690, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9701
# Step 3700, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9422
# Step 3710, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9627
# Step 3720, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9488
# Step 3730, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9463
# Step 3740, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9712
# Step 3750, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9439
# Step 3760, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9554
# Step 3770, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9441
# Step 3780, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9511
# Step 3790, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9763
# Step 3800, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9409
# Step 3810, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9550
# Step 3820, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9755
# Step 3830, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9383
# Step 3840, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9594
# Step 3850, Minibatch Loss= 0.0001, Training Accuracy= 0.9881, Test Accuracy= 0.9781
# Step 3860, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9415
# Step 3870, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9425
# Step 3880, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9666
# Step 3890, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9677
# Step 3900, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9469
# Step 3910, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9651
# Step 3920, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9396
# Step 3930, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9484
# Step 3940, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9467
# Step 3950, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9412
# Step 3960, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9720
# Step 3970, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9369
# Step 3980, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9527
# Step 3990, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9725
# Step 4000, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9269
# Step 4010, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9675
# Step 4020, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9487
# Step 4030, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.9166
# Step 4040, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9627
# Step 4050, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9351
# Step 4060, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9549
# Step 4070, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9508
# Step 4080, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.9202
# Step 4090, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9590
# Step 4100, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9391
# Step 4110, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9540
# Step 4120, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9556
# Step 4130, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9306
# Step 4140, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9580
# Step 4150, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9307
# Step 4160, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9601
# Step 4170, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9505
# Step 4180, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9280
# Step 4190, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9528
# Step 4200, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9303
# Step 4210, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9638
# Step 4220, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9513
# Step 4230, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9419
# Step 4240, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9683
# Step 4250, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9221
# Step 4260, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9635
# Step 4270, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9401
# Step 4280, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9466
# Step 4290, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9591
# Step 4300, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9415
# Step 4310, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9258
# Step 4320, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9549
# Step 4330, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9300
# Step 4340, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9495
# Step 4350, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9469
# Step 4360, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9269
# Step 4370, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9513
# Step 4380, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9489
# Step 4390, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9250
# Step 4400, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9543
# Step 4410, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9399
# Step 4420, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9446
# Step 4430, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9470
# Step 4440, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9303
# Step 4450, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9526
# Step 4460, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9520
# Step 4470, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9215
# Step 4480, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9584
# Step 4490, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9308
# Step 4500, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9463
# Step 4510, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9465
# Step 4520, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9235
# Step 4530, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9520
# Step 4540, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9360
# Step 4550, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9280
# Step 4560, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9514
# Step 4570, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9304
# Step 4580, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9349
# Step 4590, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9542
# Step 4600, Minibatch Loss= 0.0002, Training Accuracy= 0.9877, Test Accuracy= 0.8982
# Step 4610, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9155
# Step 4620, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9588
# Step 4630, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9469
# Step 4640, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9542
# Step 4650, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9418
# Step 4660, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9179
# Step 4670, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9170
# Step 4680, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9524
# Step 4690, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9303
# Step 4700, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9543
# Step 4710, Minibatch Loss= 0.0000, Training Accuracy= 0.9934, Test Accuracy= 0.9443
# Step 4720, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9165
# Step 4730, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9530
# Step 4740, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9318
# Step 4750, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9518
# Step 4760, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9454
# Step 4770, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9242
# Step 4780, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9508
# Step 4790, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9350
# Step 4800, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9179
# Step 4810, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9411
# Step 4820, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9210
# Step 4830, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9516
# Step 4840, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9342
# Step 4850, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9240
# Step 4860, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9471
# Step 4870, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9455
# Step 4880, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9333
# Step 4890, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9388
# Step 4900, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9252
# Step 4910, Minibatch Loss= 0.0000, Training Accuracy= 0.9934, Test Accuracy= 0.9417
# Step 4920, Minibatch Loss= 0.0001, Training Accuracy= 0.9878, Test Accuracy= 0.9493
# Step 4930, Minibatch Loss= 0.0005, Training Accuracy= 0.9766, Test Accuracy= 0.8488
# Step 4940, Minibatch Loss= 0.0034, Training Accuracy= 0.9413, Test Accuracy= 0.6300
# Step 4950, Minibatch Loss= 0.0352, Training Accuracy= 0.8123, Test Accuracy= 0.3880
# Step 4960, Minibatch Loss= 0.0061, Training Accuracy= 0.9216, Test Accuracy= 0.5502
# Step 4970, Minibatch Loss= 0.0021, Training Accuracy= 0.9545, Test Accuracy= 0.8860
# Step 4980, Minibatch Loss= 0.0012, Training Accuracy= 0.9654, Test Accuracy= 0.8535
# Step 4990, Minibatch Loss= 0.0007, Training Accuracy= 0.9737, Test Accuracy= 0.8675
# Step 5000, Minibatch Loss= 0.0005, Training Accuracy= 0.9787, Test Accuracy= 0.8618
# Step 5010, Minibatch Loss= 0.0003, Training Accuracy= 0.9818, Test Accuracy= 0.8599
# Step 5020, Minibatch Loss= 0.0002, Training Accuracy= 0.9846, Test Accuracy= 0.8785
# Step 5030, Minibatch Loss= 0.0005, Training Accuracy= 0.9779, Test Accuracy= 0.9140
# Step 5040, Minibatch Loss= 0.0002, Training Accuracy= 0.9861, Test Accuracy= 0.8713
# Step 5050, Minibatch Loss= 0.0002, Training Accuracy= 0.9858, Test Accuracy= 0.8741
# Step 5060, Minibatch Loss= 0.0002, Training Accuracy= 0.9873, Test Accuracy= 0.8894
# Step 5070, Minibatch Loss= 0.0002, Training Accuracy= 0.9877, Test Accuracy= 0.8953
# Step 5080, Minibatch Loss= 0.0001, Training Accuracy= 0.9880, Test Accuracy= 0.9014
# Step 5090, Minibatch Loss= 0.0001, Training Accuracy= 0.9884, Test Accuracy= 0.9074
# Step 5100, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.9124
# Step 5110, Minibatch Loss= 0.0001, Training Accuracy= 0.9888, Test Accuracy= 0.9158
# Step 5120, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.9190
# Step 5130, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.9208
# Step 5140, Minibatch Loss= 0.0001, Training Accuracy= 0.9891, Test Accuracy= 0.9227
# Step 5150, Minibatch Loss= 0.0001, Training Accuracy= 0.9892, Test Accuracy= 0.9240
# Step 5160, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9254
# Step 5170, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.9272
# Step 5180, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9286
# Step 5190, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9290
# Step 5200, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9297
# Step 5210, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9295
# Step 5220, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9304
# Step 5230, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.9364
# Step 5240, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9323
# Step 5250, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9293
# Step 5260, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9300
# Step 5270, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9257
# Step 5280, Minibatch Loss= 0.0001, Training Accuracy= 0.9887, Test Accuracy= 0.9226
# Step 5290, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9346
# Step 5300, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9293
# Step 5310, Minibatch Loss= 0.0001, Training Accuracy= 0.9880, Test Accuracy= 0.9196
# Step 5320, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.9339
# Step 5330, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9230
# Step 5340, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9289
# Step 5350, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9261
# Step 5360, Minibatch Loss= 0.0001, Training Accuracy= 0.9881, Test Accuracy= 0.9200
# Step 5370, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9349
# Step 5380, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9250
# Step 5390, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9301
# Step 5400, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9362
# Step 5410, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9218
# Step 5420, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9137
# Step 5430, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9189
# Step 5440, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9225
# Step 5450, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9275
# Step 5460, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9289
# Step 5470, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9298
# Step 5480, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9337
# Step 5490, Minibatch Loss= 0.0001, Training Accuracy= 0.9879, Test Accuracy= 0.9445
# Step 5500, Minibatch Loss= 0.0001, Training Accuracy= 0.9887, Test Accuracy= 0.9216
# Step 5510, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9243
# Step 5520, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9273
# Step 5530, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9357
# Step 5540, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9369
# Step 5550, Minibatch Loss= 0.0002, Training Accuracy= 0.9867, Test Accuracy= 0.9441
# Step 5560, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9353
# Step 5570, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.9332
# Step 5580, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9291
# Step 5590, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9359
# Step 5600, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9472
# Step 5610, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9342
# Step 5620, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9357
# Step 5630, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9352
# Step 5640, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9315
# Step 5650, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9390
# Step 5660, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9395
# ...
# Step 8110, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9336
# Step 8120, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9469
# Step 8130, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9399
# Step 8140, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9422
# Step 8150, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9335
# Step 8160, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9469
# Step 8170, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9315
# Step 8180, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9488
# Step 8190, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9361
# Step 8200, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9315
# Step 8210, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9407
# Step 8220, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9480
# Step 8230, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9384
# Step 8240, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9393
# Step 8250, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9521
# Step 8260, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9401
# Step 8270, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9403
# Step 8280, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9446
# Step 8290, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9477
# Step 8300, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9435
# Step 8310, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9486
# Step 8320, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9307
# Step 8330, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9408
# Step 8340, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9465
# Step 8350, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9371
# Step 8360, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9488
# Step 8370, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9396
# Step 8380, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9371
# Step 8390, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9461
# Step 8400, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9384
# Step 8410, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9452
# Step 8420, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9500
# Step 8430, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9358
# Step 8440, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9484
# Step 8450, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9425
# Step 8460, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9329
# Step 8470, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9430
# Step 8480, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9487
# Step 8490, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9259
# Step 8500, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9314
# Step 8510, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9427
# Step 8520, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9475
# Step 8530, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9445
# Step 8540, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9437
# Step 8550, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9517
# Step 8560, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9289
# Step 8570, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9376
# Step 8580, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9474
# Step 8590, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9394
# Step 8600, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9470
# Step 8610, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9383
# Step 8620, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9408
# Step 8630, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9458
# Step 8640, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.9513
# Step 8650, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9454
# Step 8660, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9420
# Step 8670, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9443
# Step 8680, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9401
# Step 8690, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9474
# Step 8700, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9408
# Step 8710, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9492
# Step 8720, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9285
# Step 8730, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9389
# Step 8740, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9428
# Step 8750, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9513
# Step 8760, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9395
# Step 8770, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9418
# Step 8780, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9520
# Step 8790, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9333
# Step 8800, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9365
# Step 8810, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9390
# Step 8820, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9502
# Step 8830, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9318
# Step 8840, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9363
# Step 8850, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9425
# Step 8860, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9479
# Step 8870, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9426
# Step 8880, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9433
# Step 8890, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9461
# Step 8900, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9439
# Step 8910, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9371
# Step 8920, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9512
# Step 8930, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9479
# Step 8940, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9272
# Step 8950, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9339
# Step 8960, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9396
# Step 8970, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9509
# Step 8980, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9439
# Step 8990, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9431
# Step 9000, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9482
# Step 9010, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9466
# Step 9020, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9508
# Step 9030, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9358
# Step 9040, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9491
# Step 9050, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9432
# Step 9060, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9491
# Step 9070, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9419
# Step 9080, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9465
# Step 9090, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9392
# Step 9100, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9505
# Step 9110, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9486
# Step 9120, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9473
# Step 9130, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9470
# Step 9140, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9444
# Step 9150, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9331
# Step 9160, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9344
# Step 9170, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9467
# Step 9180, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9444
# Step 9190, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9464
# Step 9200, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9474
# Step 9210, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9393
# Step 9220, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9492
# Step 9230, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9416
# Step 9240, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9422
# Step 9250, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9485
# Step 9260, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9423
# Step 9270, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9450
# Step 9280, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9343
# Step 9290, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9442
# Step 9300, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9460
# Step 9310, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9465
# Step 9320, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9388
# Step 9330, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9299
# Step 9340, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9336
# Step 9350, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9401
# Step 9360, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9506
# Step 9370, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9381
# Step 9380, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9373
# Step 9390, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9426
# Step 9400, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9436
# Step 9410, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9470
# Step 9420, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9455
# Step 9430, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9392
# Step 9440, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9452
# Step 9450, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9465
# Step 9460, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9361
# Step 9470, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9479
# Step 9480, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9435
# Step 9490, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9340
# Step 9500, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9486
# Step 9510, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9381
# Step 9520, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9443
# Step 9530, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9466
# Step 9540, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9405
# Step 9550, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9374
# Step 9560, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9408
# Step 9570, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9491
# Step 9580, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9308
# Step 9590, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9432
# Step 9600, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9402
# Step 9610, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9420
# Step 9620, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9388
# Step 9630, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9419
# Step 9640, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9422
# Step 9650, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9397
# Step 9660, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9385
# Step 9670, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9396
# Step 9680, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9446
# Step 9690, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9459
# Step 9700, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9364
# Step 9710, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9406
# Step 9720, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9453
# Step 9730, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9396
# Step 9740, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9367
# Step 9750, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9413
# Step 9760, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9415
# Step 9770, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9266
# Step 9780, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9310
# Step 9790, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9417
# Step 9800, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9454
# Step 9810, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.9445
# Step 9820, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.9258
# Step 9830, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9245
# Step 9840, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9316
# Step 9850, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9336
# Step 9860, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9423
# Step 9870, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9453
# Step 9880, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9385
# Step 9890, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9259
# Step 9900, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9303
# Step 9910, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9390
# Step 9920, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9411
# Step 9930, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9427
# Step 9940, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9417
# Step 9950, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9350
# Step 9960, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9457
# Step 9970, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9422
# Step 9980, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9421
# Step 9990, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9411
# Step 10000, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9351

# %%
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    pred00 = session.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = session.run([prediction2], feed_dict={X: test_data, is_training: False})
    pred02 = session.run([prediction2], feed_dict={X: trainX.reshape(-1,4,1), is_training: False})
# Out:
# W0726 11:58:23.458600 139824759461632 deprecation.py:323] From /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred02).reshape(-1,1)[-200:])
plt.plot(np.array(trainX).reshape(-1,)[-200:],c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred01).reshape(-1,1))
plt.plot(np.array(testY).reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

x=list(range(0,len(pred00[0])))
y1=np.array(pred01).reshape(1,-1)[0]+2*np.std(np.array(pred01).reshape(1,-1))
y2=np.array(pred01).reshape(1,-1)[0]-2*np.std(np.array(pred01).reshape(1,-1))
fig, ax1 = plt.subplots(1, 1, sharex=True)
ax1.plot(np.array(pred01).reshape(1,-1)[0],'--',color='blue',alpha=0.5)
ax1.fill_between(x, y1, y2,color='blue',alpha=0.3)
ax1.plot(x,np.array(testY).reshape(-1,),c='red')
plt.xlabel('Days')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R2',r2_score(testY.reshape(1,-1)[0],np.array(pred01).reshape(1,-1)[0]))
# Out:
# R2 0.8593317366236581

# %%
x_test=testX[0].reshape(-1,4,1)
prev=[]
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    for i in range(0,21):
        pred02 = session.run([prediction2], feed_dict={X: x_test, is_training: False})[0][0]
        prev.append(pred02)
        #print(pred02)
        x_test=np.concatenate([x_test[0][1:4],[pred02]],axis=0).reshape(-1,4,1)
        #print(x_test)

# %%
limit=8

# %%
plt.plot(np.array(prev)[0:limit].reshape(-1,1))
plt.plot(np.array(testY)[0:limit].reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

# %%
x=list(range(0,len(prev[0:limit])))
y1=np.array(prev).reshape(1,-1)[0][0:limit]+np.linspace(1.3,2,np.array(prev)[0:limit].shape[0])*np.std(np.array(prev).reshape(1,-1)[0:limit])
y2=np.array(prev).reshape(1,-1)[0][0:limit]-np.linspace(1.3,2,np.array(prev)[0:limit].shape[0])*np.std(np.array(prev).reshape(1,-1)[0:limit])
fig, ax1 = plt.subplots(1, 1, sharex=True)
ax1.plot(np.array(prev).reshape(1,-1)[0][0:limit],'--',color='blue',alpha=0.5)
ax1.fill_between(x, y1, y2,color='blue',alpha=0.3)
ax1.plot(x,np.array(testY).reshape(-1,)[0:limit],c='red')
plt.xlabel('Days')
plt.show()

real=(np.array(testY)[0:limit].reshape(-1,)[-1]/np.array(testY)[0:limit].reshape(-1,)[0]-1)*100
prevista=(np.array(prev)[0:limit].reshape(-1,1)[-1]/np.array(prev)[0:limit].reshape(-1,1)[0]-1)*100
print('Variação Real',"%.2f" % real + '%')
print('Variação Prevista',["%.2f" % prevista+'%'])
print('Erro',["%.2f" % float((prevista-real))+'%'])
# Out:
# Variação Real 8.50%
# Variação Prevista ['6.81%']
# Erro ['-1.69%']
