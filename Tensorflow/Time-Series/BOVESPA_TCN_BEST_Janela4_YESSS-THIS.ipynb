# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
#pip install pandas-datareader

stock = 'GGBR4.SA'
source = 'yahoo'

# Set date range (Google went public August 19, 2004)
start = datetime.datetime(2004, 8, 19)
end = datetime.datetime(2019, 7, 19)

# Collect Google stock data
goog_df = data.DataReader(stock, source, start, end)

dataset = goog_df['Adj Close']
print(len(dataset))
goog_df['Adj Close'].plot(kind='line', grid=True, title='GOOG Adjusted Closes, IPO through 2016')
# Out:
# 3628

# %%
import tensorflow as tf
import pandas as pd  
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow_probability as tfp


dataset = np.array(dataset.astype('float32')).reshape(-1,1)

def norm(x):
    return (x-np.min(x))/(np.max(x)-np.min(x))

#dataset=norm(dataset)

look_back=4
np.random.seed(7)
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.99)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))

def create_dataset(dataset, look_back=look_back):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX

trainY = trainY.reshape(len(trainY), 1)
testY = testY.reshape(len(testY), 1)
trainY

X0=trainX
Y0=trainY
# Out:
# 3591 37

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
tfd = tfp.distributions

class TemporalConvNet(tf.layers.Layer):
    def __init__(self, num_channels, kernel_size=2, dropout=0.2,
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalConvNet, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )
        self.layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            out_channels = num_channels[i]
            self.layers.append(
                TemporalBlock(out_channels, kernel_size, strides=1, dilation_rate=dilation_size,
                              dropout=dropout, name="tblock_{}".format(i))
            )
    
    def call(self, inputs, training=True):
        outputs = inputs
        for layer in self.layers:
            outputs = layer(outputs, training=training)
        return outputs

learning_rate = 0.001
display_step = 10
num_input = 1
num_hidden = 35
num_classes = 1

dropout = 0.1
kernel_size = 8
levels = 6

class CausalConv1D(tf.layers.Conv1D):
    def __init__(self, filters,
               kernel_size,
               strides=1,
               dilation_rate=1,
               activation=None,
               use_bias=True,
               kernel_initializer=None,
               bias_initializer=tf.zeros_initializer(),
               kernel_regularizer=None,
               bias_regularizer=None,
               activity_regularizer=None,
               kernel_constraint=None,
               bias_constraint=None,
               trainable=True,
               name=None,
               **kwargs):
        super(CausalConv1D, self).__init__(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            padding='valid',
            data_format='channels_last',
            dilation_rate=dilation_rate,
            activation=activation,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
            activity_regularizer=activity_regularizer,
            kernel_constraint=kernel_constraint,
            bias_constraint=bias_constraint,
            trainable=trainable,
            name=name, **kwargs
        )
       
    def call(self, inputs):
        padding = (self.kernel_size[0] - 1) * self.dilation_rate[0]
        inputs = tf.pad(inputs, tf.constant([(0, 0,), (1, 0), (0, 0)]) * padding)
        return super(CausalConv1D, self).call(inputs)



class TemporalBlock(tf.layers.Layer):
    def __init__(self, n_outputs, kernel_size, strides, dilation_rate, dropout=0.1, 
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalBlock, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )        
        self.dropout = dropout
        self.n_outputs = n_outputs
        self.conv1 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv1")
        self.conv2 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv2")
        self.down_sample = None

    
    def build(self, input_shape):
        channel_dim = 2
        self.dropout1 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        self.dropout2 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        if input_shape[channel_dim] != self.n_outputs:
            self.down_sample = tf.layers.Dense(self.n_outputs, activation=None)
    
    def call(self, inputs, training=True):
        x = self.conv1(inputs)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout1(x, training=training)
        x = self.conv2(x)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout2(x, training=training)
        #x = tfp.layers.DistributionLambda(make_distribution_fn=lambda t: tfd.Normal(loc=t, scale=1))(x)
        #x = tf.contrib.layers.layer_norm(x)
        #x = tf.layers.dense(inputs=x,units=3)
        if self.down_sample is not None:
          inputs = self.down_sample(inputs)
        return tf.nn.relu(x)



tf.reset_default_graph()
graph = tf.Graph()
with graph.as_default():
    tf.set_random_seed(2)
    
    X = tf.placeholder("float", [None, look_back,1])
    Y = tf.placeholder("float", [None, num_classes])
    is_training = tf.placeholder("bool")
    
    logits = tf.layers.dense(
        TemporalConvNet([num_hidden] * levels, kernel_size, dropout)(
            X, training=is_training),
        num_classes, activation=None, 
        kernel_initializer=tf.glorot_uniform_initializer()
    )
    print(logits)

    mm,_=tf.nn.moments(tf.reshape(tf.nn.relu(logits),[-1,look_back]),axes=[1])
    prediction=tf.nn.relu(logits)
    
    prediction2 = tf.reshape(tf.cast(mm,tf.float32),[-1,1])
    
    loss_op = tf.reduce_mean(tf.losses.mean_squared_error(
        labels=Y,predictions=prediction2))
    
    accuracy=1-tf.sqrt(loss_op)

    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    train_op = optimizer.minimize(loss_op)


    saver = tf.train.Saver()
    print("All parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.global_variables()]))
    print("Trainable parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()]))

def next_batch(num, data, labels):
    idx = np.arange(0 , len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    return np.asarray(data_shuffle).astype(np.float32), np.asarray(labels_shuffle).astype(np.float32)

log_dir = "/home/rubensvectomobile/BOVESPA/"
tb_writer = tf.summary.FileWriter(log_dir, graph)
config = tf.ConfigProto()
config.gpu_options.allow_growth = False
config.gpu_options.per_process_gpu_memory_fraction = 0.7
best_val_acc = 0.94

training_epochs = 1300
batch_size = X0.shape[0]


X0=X0.reshape(-1,look_back,1)
testX=testX.reshape(-1,look_back,1)
# Out:
# Tensor("dense/BiasAdd:0", shape=(?, 4, 1), dtype=float32)
# All parameters: 328200.0
# Trainable parameters: 109446

# %%
with tf.Session(graph=graph, config=config) as sess:
    init = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
    sess.run(init)
    for step in range(1, training_epochs+1):
        Xt, Yt = next_batch(batch_size, X0, Y0)
        batch_x, batch_y = Xt,Yt
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, is_training: True})
        if step % display_step == 0 or step == 1:
            loss, acc = sess.run([loss_op, accuracy], feed_dict={
                X: batch_x, Y: batch_y, is_training: False})
            test_data = testX
            test_label = testY
            val_acc = sess.run(accuracy, feed_dict={X: test_data, Y: test_label, is_training: False})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.4f}".format(acc) + ", Test Accuracy= " + \
                  "{:.4f}".format(val_acc))
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                save_path = saver.save(sess, "/home/rubensvectomobile/BOVESPA/model.ckpt")
                print("Model saved in path: %s" % save_path)
    pred00 = sess.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = sess.run([prediction2], feed_dict={X: test_data, is_training: False})
# Out:
# Step 1, Minibatch Loss= 0.0671, Training Accuracy= 0.7410, Test Accuracy= 0.7829
# Step 10, Minibatch Loss= 0.0335, Training Accuracy= 0.8170, Test Accuracy= 0.9652
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 20, Minibatch Loss= 0.0346, Training Accuracy= 0.8139, Test Accuracy= 0.9202
# Step 30, Minibatch Loss= 0.0323, Training Accuracy= 0.8201, Test Accuracy= 0.9640
# Step 40, Minibatch Loss= 0.0476, Training Accuracy= 0.7819, Test Accuracy= 0.8529
# Step 50, Minibatch Loss= 0.0400, Training Accuracy= 0.8000, Test Accuracy= 0.8892
# Step 60, Minibatch Loss= 0.0305, Training Accuracy= 0.8252, Test Accuracy= 0.9837
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 70, Minibatch Loss= 0.0269, Training Accuracy= 0.8361, Test Accuracy= 0.9617
# Step 80, Minibatch Loss= 0.0286, Training Accuracy= 0.8308, Test Accuracy= 0.9173
# Step 90, Minibatch Loss= 0.0362, Training Accuracy= 0.8097, Test Accuracy= 0.8968
# Step 100, Minibatch Loss= 0.0309, Training Accuracy= 0.8243, Test Accuracy= 0.9383
# Step 110, Minibatch Loss= 0.0236, Training Accuracy= 0.8464, Test Accuracy= 0.9524
# Step 120, Minibatch Loss= 0.0156, Training Accuracy= 0.8753, Test Accuracy= 0.9180
# Step 130, Minibatch Loss= 0.0267, Training Accuracy= 0.8366, Test Accuracy= 0.9010
# Step 140, Minibatch Loss= 0.0183, Training Accuracy= 0.8648, Test Accuracy= 0.9574
# Step 150, Minibatch Loss= 0.0213, Training Accuracy= 0.8540, Test Accuracy= 0.9637
# Step 160, Minibatch Loss= 0.0209, Training Accuracy= 0.8553, Test Accuracy= 0.8985
# Step 170, Minibatch Loss= 0.0152, Training Accuracy= 0.8767, Test Accuracy= 0.9774
# Step 180, Minibatch Loss= 0.0162, Training Accuracy= 0.8728, Test Accuracy= 0.8719
# Step 190, Minibatch Loss= 0.0147, Training Accuracy= 0.8786, Test Accuracy= 0.8770
# Step 200, Minibatch Loss= 0.0148, Training Accuracy= 0.8782, Test Accuracy= 0.9882
# Model saved in path: /home/rubensvectomobile/BOVESPA/model.ckpt
# Step 210, Minibatch Loss= 0.0175, Training Accuracy= 0.8679, Test Accuracy= 0.9842
# Step 220, Minibatch Loss= 0.0159, Training Accuracy= 0.8738, Test Accuracy= 0.9731
# Step 230, Minibatch Loss= 0.0128, Training Accuracy= 0.8869, Test Accuracy= 0.9609
# Step 240, Minibatch Loss= 0.0115, Training Accuracy= 0.8929, Test Accuracy= 0.9164
# Step 250, Minibatch Loss= 0.0090, Training Accuracy= 0.9052, Test Accuracy= 0.9666
# Step 260, Minibatch Loss= 0.0261, Training Accuracy= 0.8383, Test Accuracy= 0.7863
# Step 270, Minibatch Loss= 0.0123, Training Accuracy= 0.8889, Test Accuracy= 0.9319
# Step 280, Minibatch Loss= 0.0063, Training Accuracy= 0.9204, Test Accuracy= 0.9824
# Step 290, Minibatch Loss= 0.0100, Training Accuracy= 0.8998, Test Accuracy= 0.8655
# Step 300, Minibatch Loss= 0.0117, Training Accuracy= 0.8918, Test Accuracy= 0.9647
# Step 310, Minibatch Loss= 0.0088, Training Accuracy= 0.9060, Test Accuracy= 0.9126
# Step 320, Minibatch Loss= 0.0103, Training Accuracy= 0.8984, Test Accuracy= 0.8966
# Step 330, Minibatch Loss= 0.0086, Training Accuracy= 0.9074, Test Accuracy= 0.9604
# Step 340, Minibatch Loss= 0.0091, Training Accuracy= 0.9047, Test Accuracy= 0.9340
# Step 350, Minibatch Loss= 0.0074, Training Accuracy= 0.9141, Test Accuracy= 0.9726
# Step 360, Minibatch Loss= 0.0076, Training Accuracy= 0.9130, Test Accuracy= 0.9164
# Step 370, Minibatch Loss= 0.0048, Training Accuracy= 0.9309, Test Accuracy= 0.9642
# Step 380, Minibatch Loss= 0.0046, Training Accuracy= 0.9322, Test Accuracy= 0.9364
# Step 390, Minibatch Loss= 0.0098, Training Accuracy= 0.9012, Test Accuracy= 0.8971
# Step 400, Minibatch Loss= 0.0076, Training Accuracy= 0.9131, Test Accuracy= 0.9262
# Step 410, Minibatch Loss= 0.0048, Training Accuracy= 0.9309, Test Accuracy= 0.9842
# Step 420, Minibatch Loss= 0.0035, Training Accuracy= 0.9407, Test Accuracy= 0.9708
# Step 430, Minibatch Loss= 0.0040, Training Accuracy= 0.9365, Test Accuracy= 0.9642
# Step 440, Minibatch Loss= 0.0092, Training Accuracy= 0.9043, Test Accuracy= 0.9567
# Step 450, Minibatch Loss= 0.0044, Training Accuracy= 0.9337, Test Accuracy= 0.9744
# Step 460, Minibatch Loss= 0.0046, Training Accuracy= 0.9322, Test Accuracy= 0.9751
# Step 470, Minibatch Loss= 0.0047, Training Accuracy= 0.9316, Test Accuracy= 0.9847
# Step 480, Minibatch Loss= 0.0043, Training Accuracy= 0.9347, Test Accuracy= 0.9848
# Step 490, Minibatch Loss= 0.0079, Training Accuracy= 0.9109, Test Accuracy= 0.9545
# Step 500, Minibatch Loss= 0.0110, Training Accuracy= 0.8950, Test Accuracy= 0.9412
# Step 510, Minibatch Loss= 0.0039, Training Accuracy= 0.9372, Test Accuracy= 0.9443
# Step 520, Minibatch Loss= 0.0033, Training Accuracy= 0.9426, Test Accuracy= 0.9509
# Step 530, Minibatch Loss= 0.0040, Training Accuracy= 0.9370, Test Accuracy= 0.9675
# Step 540, Minibatch Loss= 0.0037, Training Accuracy= 0.9391, Test Accuracy= 0.9798
# Step 550, Minibatch Loss= 0.0065, Training Accuracy= 0.9191, Test Accuracy= 0.9148
# Step 560, Minibatch Loss= 0.0043, Training Accuracy= 0.9346, Test Accuracy= 0.9723
# Step 570, Minibatch Loss= 0.0044, Training Accuracy= 0.9338, Test Accuracy= 0.9524
# Step 580, Minibatch Loss= 0.0041, Training Accuracy= 0.9357, Test Accuracy= 0.9791
# Step 590, Minibatch Loss= 0.0044, Training Accuracy= 0.9337, Test Accuracy= 0.9817
# Step 600, Minibatch Loss= 0.0040, Training Accuracy= 0.9364, Test Accuracy= 0.9387
# Step 610, Minibatch Loss= 0.0079, Training Accuracy= 0.9111, Test Accuracy= 0.9762
# Step 620, Minibatch Loss= 0.0065, Training Accuracy= 0.9197, Test Accuracy= 0.9121
# Step 630, Minibatch Loss= 0.0059, Training Accuracy= 0.9232, Test Accuracy= 0.9687
# Step 640, Minibatch Loss= 0.0029, Training Accuracy= 0.9457, Test Accuracy= 0.9561
# Step 650, Minibatch Loss= 0.0029, Training Accuracy= 0.9462, Test Accuracy= 0.9751
# Step 660, Minibatch Loss= 0.0052, Training Accuracy= 0.9276, Test Accuracy= 0.9396
# Step 670, Minibatch Loss= 0.0027, Training Accuracy= 0.9480, Test Accuracy= 0.9723
# Step 680, Minibatch Loss= 0.0038, Training Accuracy= 0.9387, Test Accuracy= 0.9707
# Step 690, Minibatch Loss= 0.0021, Training Accuracy= 0.9543, Test Accuracy= 0.9784
# Step 700, Minibatch Loss= 0.0021, Training Accuracy= 0.9537, Test Accuracy= 0.9809
# Step 710, Minibatch Loss= 0.0031, Training Accuracy= 0.9439, Test Accuracy= 0.9450
# Step 720, Minibatch Loss= 0.0033, Training Accuracy= 0.9429, Test Accuracy= 0.9867

# %%
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    pred00 = session.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = session.run([prediction2], feed_dict={X: test_data, is_training: False})

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred01).reshape(-1,1))
plt.plot(np.array(testY).reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

x=list(range(0,len(pred00[0])))
y1=np.array(pred01).reshape(1,-1)[0]+2*np.std(np.array(pred01).reshape(1,-1))
y2=np.array(pred01).reshape(1,-1)[0]-2*np.std(np.array(pred01).reshape(1,-1))
fig, ax1 = plt.subplots(1, 1, sharex=True)
ax1.plot(np.array(pred01).reshape(1,-1)[0],'--',color='blue',alpha=0.5)
ax1.fill_between(x, y1, y2,color='blue',alpha=0.3)
ax1.plot(x,np.array(testY).reshape(-1,),c='red')
plt.xlabel('Days')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R2',r2_score(testY.reshape(1,-1)[0],np.array(pred01).reshape(1,-1)[0]))

# %%
x_test=X0[-1].reshape(-1,4,1)
prev=[]
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    for i in range(0,21):
        pred02 = session.run([prediction2], feed_dict={X: x_test, is_training: False})[0][0]
        prev.append(pred02)
        #print(pred02)
        x_test=np.concatenate([x_test[0][1:4],[pred02]],axis=0).reshape(-1,4,1)
        #print(x_test)

# %%
limit=8

# %%
plt.plot(np.array(prev)[0:limit].reshape(-1,1))
plt.plot(np.array(testY)[0:limit].reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

# %%
X0[-1]

# %%
Y0
