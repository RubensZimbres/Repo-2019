# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
#pip install pandas-datareader

stock = 'RENT3.SA'
source = 'yahoo'

# Set date range (Google went public August 19, 2004)
start = datetime.datetime(2005, 8, 19)
end = datetime.datetime(2019, 8, 6)

# Collect Google stock data
goog_df = data.DataReader(stock, source, start, end)

dataset = goog_df['Adj Close']
print(len(dataset))
goog_df['Adj Close'].plot(kind='line', grid=True, title='GOOG Adjusted Closes, IPO through 2016')
# Out:
# 3455

# %%
goog_df['Adj Close'][-1]
# Out:
# 44.900001525878906

# %%
import tensorflow as tf
import pandas as pd  
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow_probability as tfp


dataset = np.array(dataset.astype('float32')).reshape(-1,1)

def norm(x):
    return (x-np.min(x))/(np.max(x)-np.min(x))

#dataset=norm(dataset)

look_back=4
np.random.seed(7)
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.99)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))

def create_dataset(dataset, look_back=look_back):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX

trainY = trainY.reshape(len(trainY), 1)
testY = testY.reshape(len(testY), 1)
trainY

X0=trainX
Y0=trainY
# Out:
# 3420 35

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
tfd = tfp.distributions

class TemporalConvNet(tf.layers.Layer):
    def __init__(self, num_channels, kernel_size=2, dropout=0.2,
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalConvNet, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )
        self.layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            out_channels = num_channels[i]
            self.layers.append(
                TemporalBlock(out_channels, kernel_size, strides=1, dilation_rate=dilation_size,
                              dropout=dropout, name="tblock_{}".format(i))
            )
    
    def call(self, inputs, training=True):
        outputs = inputs
        for layer in self.layers:
            outputs = layer(outputs, training=training)
        return outputs

learning_rate = 0.001
display_step = 10
num_input = 1
num_hidden = 35
num_classes = 1

dropout = 0
kernel_size = 8
levels = 6

class CausalConv1D(tf.layers.Conv1D):
    def __init__(self, filters,
               kernel_size,
               strides=1,
               dilation_rate=1,
               activation=None,
               use_bias=True,
               kernel_initializer=None,
               bias_initializer=tf.zeros_initializer(),
               kernel_regularizer=None,
               bias_regularizer=None,
               activity_regularizer=None,
               kernel_constraint=None,
               bias_constraint=None,
               trainable=True,
               name=None,
               **kwargs):
        super(CausalConv1D, self).__init__(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            padding='valid',
            data_format='channels_last',
            dilation_rate=dilation_rate,
            activation=activation,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
            activity_regularizer=activity_regularizer,
            kernel_constraint=kernel_constraint,
            bias_constraint=bias_constraint,
            trainable=trainable,
            name=name, **kwargs
        )
       
    def call(self, inputs):
        padding = (self.kernel_size[0] - 1) * self.dilation_rate[0]
        inputs = tf.pad(inputs, tf.constant([(0, 0,), (1, 0), (0, 0)]) * padding)
        return super(CausalConv1D, self).call(inputs)



class TemporalBlock(tf.layers.Layer):
    def __init__(self, n_outputs, kernel_size, strides, dilation_rate, dropout=0.1, 
                 trainable=True, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalBlock, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )        
        self.dropout = dropout
        self.n_outputs = n_outputs
        self.conv1 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv1")
        self.conv2 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv2")
        self.down_sample = None

    
    def build(self, input_shape):
        channel_dim = 2
        self.dropout1 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        self.dropout2 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        if input_shape[channel_dim] != self.n_outputs:
            self.down_sample = tf.layers.Dense(self.n_outputs, activation=None)
    
    def call(self, inputs, training=True):
        x = self.conv1(inputs)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout1(x, training=training)
        x = self.conv2(x)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout2(x, training=training)
        #x = tfp.layers.DistributionLambda(make_distribution_fn=lambda t: tfd.Normal(loc=t, scale=1))(x)
        #x = tf.contrib.layers.layer_norm(x)
        #x = tf.layers.dense(inputs=x,units=3)
        if self.down_sample is not None:
          inputs = self.down_sample(inputs)
        return tf.nn.relu(x)



tf.reset_default_graph()
graph = tf.Graph()
with graph.as_default():
    tf.set_random_seed(2)
    
    X = tf.placeholder("float", [None, look_back,1])
    Y = tf.placeholder("float", [None, num_classes])
    is_training = tf.placeholder("bool")
    
    logits = tf.layers.dense(
        TemporalConvNet([num_hidden] * levels, kernel_size, dropout)(
            X, training=is_training),
        num_classes, activation=None, 
        kernel_initializer=tf.glorot_uniform_initializer()
    )
    print(logits)

    mm,_=tf.nn.moments(tf.reshape(tf.nn.relu(logits),[-1,look_back]),axes=[1])
    prediction=tf.nn.relu(logits)
    
    prediction2 = tf.reshape(tf.cast(mm,tf.float32),[-1,1])
    
    loss_op = tf.reduce_mean(tf.losses.mean_squared_error(
        labels=Y,predictions=prediction2))
    
    accuracy=1-tf.sqrt(loss_op)

    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    train_op = optimizer.minimize(loss_op)


    saver = tf.train.Saver()
    print("All parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.global_variables()]))
    print("Trainable parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()]))

def next_batch(num, data, labels):
    idx = np.arange(0 , len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    return np.asarray(data_shuffle).astype(np.float32), np.asarray(labels_shuffle).astype(np.float32)

log_dir = "/home/rubensvectomobile/BOVESPA/"
tb_writer = tf.summary.FileWriter(log_dir, graph)
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.7
best_val_acc = 0.93

training_epochs = 6000
batch_size = 128


X0=X0.reshape(-1,look_back,1)
testX=testX.reshape(-1,look_back,1)
# Out:
# Tensor("dense/BiasAdd:0", shape=(?, 4, 1), dtype=float32)
# All parameters: 328200.0
# Trainable parameters: 109446

# %%
with tf.Session(graph=graph, config=config) as sess:
    init = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
    sess.run(init)
    for step in range(1, training_epochs+1):
        Xt, Yt = next_batch(batch_size, X0, Y0)
        batch_x, batch_y = Xt,Yt
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, is_training: True})
        if step % display_step == 0 or step == 1:
            loss, acc = sess.run([loss_op, accuracy], feed_dict={
                X: batch_x, Y: batch_y, is_training: False})
            test_data = testX
            test_label = testY
            val_acc = sess.run(accuracy, feed_dict={X: test_data, Y: test_label, is_training: False})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.4f}".format(acc) + ", Test Accuracy= " + \
                  "{:.4f}".format(val_acc))
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                save_path = saver.save(sess, "/home/rubensvectomobile/BOVESPA/real/model.ckpt")
                print("Model saved in path: %s" % save_path)
    pred00 = sess.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = sess.run([prediction2], feed_dict={X: test_data, is_training: False})
# Out:
# Step 1, Minibatch Loss= 0.0633, Training Accuracy= 0.7485, Test Accuracy= 0.0715
# Step 10, Minibatch Loss= 0.0181, Training Accuracy= 0.8655, Test Accuracy= 0.3389
# Step 20, Minibatch Loss= 0.0028, Training Accuracy= 0.9471, Test Accuracy= 0.7023
# Step 30, Minibatch Loss= 0.0016, Training Accuracy= 0.9597, Test Accuracy= 0.7430
# Step 40, Minibatch Loss= 0.0008, Training Accuracy= 0.9726, Test Accuracy= 0.7563
# Step 50, Minibatch Loss= 0.0006, Training Accuracy= 0.9765, Test Accuracy= 0.8604
# Step 60, Minibatch Loss= 0.0007, Training Accuracy= 0.9739, Test Accuracy= 0.8899
# Step 70, Minibatch Loss= 0.0006, Training Accuracy= 0.9753, Test Accuracy= 0.9042
# Step 80, Minibatch Loss= 0.0003, Training Accuracy= 0.9821, Test Accuracy= 0.8709
# Step 90, Minibatch Loss= 0.0004, Training Accuracy= 0.9813, Test Accuracy= 0.7972
# Step 100, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.8661
# Step 110, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.8975
# Step 120, Minibatch Loss= 0.0002, Training Accuracy= 0.9871, Test Accuracy= 0.9281
# Step 130, Minibatch Loss= 0.0001, Training Accuracy= 0.9882, Test Accuracy= 0.9382
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 140, Minibatch Loss= 0.0004, Training Accuracy= 0.9801, Test Accuracy= 0.8739
# Step 150, Minibatch Loss= 0.0003, Training Accuracy= 0.9815, Test Accuracy= 0.9311
# Step 160, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9133
# Step 170, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9146
# Step 180, Minibatch Loss= 0.0003, Training Accuracy= 0.9823, Test Accuracy= 0.8828
# Step 190, Minibatch Loss= 0.0002, Training Accuracy= 0.9858, Test Accuracy= 0.9160
# Step 200, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9315
# Step 210, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9033
# Step 220, Minibatch Loss= 0.0010, Training Accuracy= 0.9680, Test Accuracy= 0.8166
# Step 230, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.8917
# Step 240, Minibatch Loss= 0.0003, Training Accuracy= 0.9841, Test Accuracy= 0.8456
# Step 250, Minibatch Loss= 0.0004, Training Accuracy= 0.9794, Test Accuracy= 0.9142
# Step 260, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.8677
# Step 270, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.8961
# Step 280, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.9372
# Step 290, Minibatch Loss= 0.0002, Training Accuracy= 0.9877, Test Accuracy= 0.9344
# Step 300, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.9161
# Step 310, Minibatch Loss= 0.0004, Training Accuracy= 0.9805, Test Accuracy= 0.8466
# Step 320, Minibatch Loss= 0.0014, Training Accuracy= 0.9631, Test Accuracy= 0.9414
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 330, Minibatch Loss= 0.0002, Training Accuracy= 0.9877, Test Accuracy= 0.8766
# Step 340, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9056
# Step 350, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.8943
# Step 360, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.8845
# Step 370, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.9367
# Step 380, Minibatch Loss= 0.0002, Training Accuracy= 0.9869, Test Accuracy= 0.8706
# Step 390, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.8974
# Step 400, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.8996
# Step 410, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9213
# Step 420, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.8998
# Step 430, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9236
# Step 440, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9091
# Step 450, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.9199
# Step 460, Minibatch Loss= 0.0006, Training Accuracy= 0.9753, Test Accuracy= 0.9527
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 470, Minibatch Loss= 0.0005, Training Accuracy= 0.9780, Test Accuracy= 0.8098
# Step 480, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.8467
# Step 490, Minibatch Loss= 0.0005, Training Accuracy= 0.9781, Test Accuracy= 0.9108
# Step 500, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.8838
# Step 510, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.9104
# Step 520, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9120
# Step 530, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9190
# Step 540, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9023
# Step 550, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.9289
# Step 560, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9190
# Step 570, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9192
# Step 580, Minibatch Loss= 0.0000, Training Accuracy= 0.9938, Test Accuracy= 0.9109
# Step 590, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9249
# Step 600, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9312
# Step 610, Minibatch Loss= 0.0002, Training Accuracy= 0.9866, Test Accuracy= 0.9303
# Step 620, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.8724
# Step 630, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.8698
# Step 640, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.9180
# Step 650, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.8935
# Step 660, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.8610
# Step 670, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.8890
# Step 680, Minibatch Loss= 0.0002, Training Accuracy= 0.9873, Test Accuracy= 0.9314
# Step 690, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9189
# Step 700, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9417
# Step 710, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9092
# Step 720, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9297
# Step 730, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9103
# Step 740, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.8550
# Step 750, Minibatch Loss= 0.0004, Training Accuracy= 0.9807, Test Accuracy= 0.8736
# Step 760, Minibatch Loss= 0.0002, Training Accuracy= 0.9858, Test Accuracy= 0.8422
# Step 770, Minibatch Loss= 0.0001, Training Accuracy= 0.9884, Test Accuracy= 0.8807
# Step 780, Minibatch Loss= 0.0001, Training Accuracy= 0.9881, Test Accuracy= 0.8922
# Step 790, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9089
# Step 800, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9080
# Step 810, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9097
# Step 820, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.8936
# Step 830, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.8958
# Step 840, Minibatch Loss= 0.0002, Training Accuracy= 0.9854, Test Accuracy= 0.8598
# Step 850, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.8604
# Step 860, Minibatch Loss= 0.0003, Training Accuracy= 0.9842, Test Accuracy= 0.8859
# Step 870, Minibatch Loss= 0.0003, Training Accuracy= 0.9840, Test Accuracy= 0.8361
# Step 880, Minibatch Loss= 0.0004, Training Accuracy= 0.9804, Test Accuracy= 0.9070
# Step 890, Minibatch Loss= 0.0001, Training Accuracy= 0.9882, Test Accuracy= 0.9005
# Step 900, Minibatch Loss= 0.0013, Training Accuracy= 0.9638, Test Accuracy= 0.8905
# Step 910, Minibatch Loss= 0.0002, Training Accuracy= 0.9871, Test Accuracy= 0.8453
# Step 920, Minibatch Loss= 0.0003, Training Accuracy= 0.9823, Test Accuracy= 0.8059
# Step 930, Minibatch Loss= 0.0002, Training Accuracy= 0.9858, Test Accuracy= 0.8345
# Step 940, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.8733
# Step 950, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.8953
# Step 960, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.8957
# Step 970, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.8993
# Step 980, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.8890
# Step 990, Minibatch Loss= 0.0001, Training Accuracy= 0.9892, Test Accuracy= 0.8766
# Step 1000, Minibatch Loss= 0.0002, Training Accuracy= 0.9869, Test Accuracy= 0.8742
# Step 1010, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.8547
# Step 1020, Minibatch Loss= 0.0002, Training Accuracy= 0.9876, Test Accuracy= 0.8805
# Step 1030, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.8966
# Step 1040, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9032
# Step 1050, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.8930
# Step 1060, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.8851
# Step 1070, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.8924
# Step 1080, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.8926
# Step 1090, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9102
# Step 1100, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9190
# Step 1110, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9206
# Step 1120, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.9006
# Step 1130, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.8988
# Step 1140, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.8966
# Step 1150, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9019
# Step 1160, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.8975
# Step 1170, Minibatch Loss= 0.0000, Training Accuracy= 0.9935, Test Accuracy= 0.9064
# Step 1180, Minibatch Loss= 0.0001, Training Accuracy= 0.9882, Test Accuracy= 0.9241
# Step 1190, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.9216
# Step 1200, Minibatch Loss= 0.0001, Training Accuracy= 0.9882, Test Accuracy= 0.9317
# Step 1210, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.9386
# Step 1220, Minibatch Loss= 0.0002, Training Accuracy= 0.9846, Test Accuracy= 0.8940
# Step 1230, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.8617
# Step 1240, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9034
# Step 1250, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.9106
# Step 1260, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9084
# Step 1270, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.9153
# Step 1280, Minibatch Loss= 0.0001, Training Accuracy= 0.9888, Test Accuracy= 0.8902
# Step 1290, Minibatch Loss= 0.0002, Training Accuracy= 0.9877, Test Accuracy= 0.8757
# Step 1300, Minibatch Loss= 0.0004, Training Accuracy= 0.9797, Test Accuracy= 0.8712
# Step 1310, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9040
# Step 1320, Minibatch Loss= 0.0001, Training Accuracy= 0.9880, Test Accuracy= 0.8960
# Step 1330, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.8744
# Step 1340, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.8484
# Step 1350, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.8457
# Step 1360, Minibatch Loss= 0.0002, Training Accuracy= 0.9868, Test Accuracy= 0.8521
# Step 1370, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9070
# Step 1380, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9080
# Step 1390, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.8970
# Step 1400, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.8828
# Step 1410, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.8708
# Step 1420, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.8796
# Step 1430, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.8685
# Step 1440, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.8824
# Step 1450, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.8891
# Step 1460, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.8943
# Step 1470, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.8945
# Step 1480, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9135
# Step 1490, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.8936
# Step 1500, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.8994
# Step 1510, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9025
# Step 1520, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9054
# Step 1530, Minibatch Loss= 0.0000, Training Accuracy= 0.9941, Test Accuracy= 0.9090
# Step 1540, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.8993
# Step 1550, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.9086
# Step 1560, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9110
# Step 1570, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.8879
# Step 1580, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.8990
# Step 1590, Minibatch Loss= 0.0000, Training Accuracy= 0.9944, Test Accuracy= 0.9037
# Step 1600, Minibatch Loss= 0.0000, Training Accuracy= 0.9937, Test Accuracy= 0.8969
# Step 1610, Minibatch Loss= 0.0000, Training Accuracy= 0.9936, Test Accuracy= 0.9094
# Step 1620, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.8956
# Step 1630, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9059
# Step 1640, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.9038
# Step 1650, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9016
# Step 1660, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.8925
# Step 1670, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9085
# Step 1680, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9228
# Step 1690, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.9231
# Step 1700, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9150
# Step 1710, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9189
# Step 1720, Minibatch Loss= 0.0004, Training Accuracy= 0.9812, Test Accuracy= 0.8644
# Step 1730, Minibatch Loss= 0.0001, Training Accuracy= 0.9897, Test Accuracy= 0.8902
# Step 1740, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9058
# Step 1750, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.8791
# Step 1760, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.8966
# Step 1770, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9066
# Step 1780, Minibatch Loss= 0.0001, Training Accuracy= 0.9880, Test Accuracy= 0.9209
# Step 1790, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9148
# Step 1800, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9199
# Step 1810, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.8908
# Step 1820, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.8995
# Step 1830, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.8764
# Step 1840, Minibatch Loss= 0.0001, Training Accuracy= 0.9885, Test Accuracy= 0.8751
# Step 1850, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.8985
# Step 1860, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.8938
# Step 1870, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.8628
# Step 1880, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.8810
# Step 1890, Minibatch Loss= 0.0002, Training Accuracy= 0.9863, Test Accuracy= 0.8908
# Step 1900, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.8827
# Step 1910, Minibatch Loss= 0.0001, Training Accuracy= 0.9914, Test Accuracy= 0.8455
# Step 1920, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.8756
# Step 1930, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.8964
# Step 1940, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.8863
# Step 1950, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.8704
# Step 1960, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9048
# Step 1970, Minibatch Loss= 0.0001, Training Accuracy= 0.9884, Test Accuracy= 0.9155
# Step 1980, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.8986
# Step 1990, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9024
# Step 2000, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9077
# Step 2010, Minibatch Loss= 0.0002, Training Accuracy= 0.9854, Test Accuracy= 0.9112
# Step 2020, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.9098
# Step 2030, Minibatch Loss= 0.0003, Training Accuracy= 0.9826, Test Accuracy= 0.9248
# Step 2040, Minibatch Loss= 0.0004, Training Accuracy= 0.9795, Test Accuracy= 0.8783
# Step 2050, Minibatch Loss= 0.0002, Training Accuracy= 0.9870, Test Accuracy= 0.8833
# Step 2060, Minibatch Loss= 0.0001, Training Accuracy= 0.9879, Test Accuracy= 0.8967
# Step 2070, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.8558
# Step 2080, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.8958
# Step 2090, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.8732
# Step 2100, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.8821
# Step 2110, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.8905
# Step 2120, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.8843
# Step 2130, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.8858
# Step 2140, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.8607
# Step 2150, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.8763
# Step 2160, Minibatch Loss= 0.0002, Training Accuracy= 0.9868, Test Accuracy= 0.9008
# Step 2170, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.8788
# Step 2180, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.8870
# Step 2190, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.8930
# Step 2200, Minibatch Loss= 0.0000, Training Accuracy= 0.9936, Test Accuracy= 0.8918
# Step 2210, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9008
# Step 2220, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.8867
# Step 2230, Minibatch Loss= 0.0000, Training Accuracy= 0.9934, Test Accuracy= 0.9035
# Step 2240, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.8932
# Step 2250, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9028
# Step 2260, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9105
# Step 2270, Minibatch Loss= 0.0000, Training Accuracy= 0.9952, Test Accuracy= 0.9156
# Step 2280, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9129
# Step 2290, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.8859
# Step 2300, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9187
# Step 2310, Minibatch Loss= 0.0002, Training Accuracy= 0.9876, Test Accuracy= 0.9171
# Step 2320, Minibatch Loss= 0.0002, Training Accuracy= 0.9876, Test Accuracy= 0.8973
# Step 2330, Minibatch Loss= 0.0001, Training Accuracy= 0.9890, Test Accuracy= 0.8864
# Step 2340, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.8781
# Step 2350, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.8703
# Step 2360, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.8943
# Step 2370, Minibatch Loss= 0.0001, Training Accuracy= 0.9887, Test Accuracy= 0.8996
# Step 2380, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.8856
# Step 2390, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.8930
# Step 2400, Minibatch Loss= 0.0003, Training Accuracy= 0.9826, Test Accuracy= 0.9131
# Step 2410, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9235
# Step 2420, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9006
# Step 2430, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.8675
# Step 2440, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.8579
# Step 2450, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.8538
# Step 2460, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.8755
# Step 2470, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.8806
# Step 2480, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.8787
# Step 2490, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.8720
# Step 2500, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.8734
# Step 2510, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.8721
# Step 2520, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.9027
# Step 2530, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.9235
# Step 2540, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.9241
# Step 2550, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.8871
# Step 2560, Minibatch Loss= 0.0003, Training Accuracy= 0.9814, Test Accuracy= 0.8755
# Step 2570, Minibatch Loss= 0.0001, Training Accuracy= 0.9887, Test Accuracy= 0.8485
# Step 2580, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.8655
# Step 2590, Minibatch Loss= 0.0002, Training Accuracy= 0.9869, Test Accuracy= 0.8580
# Step 2600, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.8837
# Step 2610, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.8930
# Step 2620, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.8948
# Step 2630, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.8832
# Step 2640, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.8885
# Step 2650, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.8910
# Step 2660, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.8953
# Step 2670, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.8821
# Step 2680, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.8900
# Step 2690, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.8814
# Step 2700, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9088
# Step 2710, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.8855
# Step 2720, Minibatch Loss= 0.0001, Training Accuracy= 0.9907, Test Accuracy= 0.8816
# Step 2730, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.9017
# Step 2740, Minibatch Loss= 0.0001, Training Accuracy= 0.9928, Test Accuracy= 0.9135
# Step 2750, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.9026
# Step 2760, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9000
# Step 2770, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.8855
# Step 2780, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9155
# Step 2790, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9041
# Step 2800, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.8978
# Step 2810, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9017
# Step 2820, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9078
# Step 2830, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9099
# Step 2840, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.8996
# Step 2850, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.8798
# Step 2860, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9169
# Step 2870, Minibatch Loss= 0.0000, Training Accuracy= 0.9936, Test Accuracy= 0.9326
# Step 2880, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9312
# Step 2890, Minibatch Loss= 0.0001, Training Accuracy= 0.9903, Test Accuracy= 0.8837
# Step 2900, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.8821
# Step 2910, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9083
# Step 2920, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.9215
# Step 2930, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.9137
# Step 2940, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9211
# Step 2950, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.8734
# Step 2960, Minibatch Loss= 0.0001, Training Accuracy= 0.9886, Test Accuracy= 0.8942
# Step 2970, Minibatch Loss= 0.0001, Training Accuracy= 0.9893, Test Accuracy= 0.8617
# Step 2980, Minibatch Loss= 0.0002, Training Accuracy= 0.9874, Test Accuracy= 0.8726
# Step 2990, Minibatch Loss= 0.0003, Training Accuracy= 0.9819, Test Accuracy= 0.8927
# Step 3000, Minibatch Loss= 0.0006, Training Accuracy= 0.9759, Test Accuracy= 0.8360
# Step 3010, Minibatch Loss= 0.0002, Training Accuracy= 0.9875, Test Accuracy= 0.8333
# Step 3020, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.8919
# Step 3030, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.8895
# Step 3040, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.8948
# Step 3050, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.8897
# Step 3060, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.8990
# Step 3070, Minibatch Loss= 0.0001, Training Accuracy= 0.9911, Test Accuracy= 0.8988
# Step 3080, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.8930
# Step 3090, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.9052
# Step 3100, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9209
# Step 3110, Minibatch Loss= 0.0004, Training Accuracy= 0.9789, Test Accuracy= 0.9175
# Step 3120, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.9050
# Step 3130, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.8909
# Step 3140, Minibatch Loss= 0.0002, Training Accuracy= 0.9868, Test Accuracy= 0.8892
# Step 3150, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.9005
# Step 3160, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.8965
# Step 3170, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.8982
# Step 3180, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.8905
# Step 3190, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.8750
# Step 3200, Minibatch Loss= 0.0001, Training Accuracy= 0.9919, Test Accuracy= 0.8841
# Step 3210, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.8832
# Step 3220, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.8942
# Step 3230, Minibatch Loss= 0.0003, Training Accuracy= 0.9826, Test Accuracy= 0.9143
# Step 3240, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9184
# Step 3250, Minibatch Loss= 0.0001, Training Accuracy= 0.9901, Test Accuracy= 0.9224
# Step 3260, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.9129
# Step 3270, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9246
# Step 3280, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.9108
# Step 3290, Minibatch Loss= 0.0001, Training Accuracy= 0.9899, Test Accuracy= 0.9056
# Step 3300, Minibatch Loss= 0.0001, Training Accuracy= 0.9915, Test Accuracy= 0.9012
# Step 3310, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.9098
# Step 3320, Minibatch Loss= 0.0001, Training Accuracy= 0.9902, Test Accuracy= 0.8922
# Step 3330, Minibatch Loss= 0.0000, Training Accuracy= 0.9932, Test Accuracy= 0.9003
# Step 3340, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.9074
# Step 3350, Minibatch Loss= 0.0000, Training Accuracy= 0.9929, Test Accuracy= 0.8999
# Step 3360, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.8900
# Step 3370, Minibatch Loss= 0.0000, Training Accuracy= 0.9945, Test Accuracy= 0.8861
# Step 3380, Minibatch Loss= 0.0001, Training Accuracy= 0.9922, Test Accuracy= 0.8741
# Step 3390, Minibatch Loss= 0.0000, Training Accuracy= 0.9936, Test Accuracy= 0.9083
# Step 3400, Minibatch Loss= 0.0001, Training Accuracy= 0.9923, Test Accuracy= 0.8827
# Step 3410, Minibatch Loss= 0.0001, Training Accuracy= 0.9926, Test Accuracy= 0.8700
# Step 3420, Minibatch Loss= 0.0001, Training Accuracy= 0.9879, Test Accuracy= 0.8719
# Step 3430, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9057
# Step 3440, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.8928
# Step 3450, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.8951
# Step 3460, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.8632
# Step 3470, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.8742
# Step 3480, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.8938
# Step 3490, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9052
# Step 3500, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.8851
# Step 3510, Minibatch Loss= 0.0001, Training Accuracy= 0.9917, Test Accuracy= 0.8849
# Step 3520, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.8890
# Step 3530, Minibatch Loss= 0.0001, Training Accuracy= 0.9925, Test Accuracy= 0.8804
# Step 3540, Minibatch Loss= 0.0000, Training Accuracy= 0.9931, Test Accuracy= 0.9148
# Step 3550, Minibatch Loss= 0.0001, Training Accuracy= 0.9906, Test Accuracy= 0.9281
# Step 3560, Minibatch Loss= 0.0000, Training Accuracy= 0.9938, Test Accuracy= 0.9215
# Step 3570, Minibatch Loss= 0.0001, Training Accuracy= 0.9924, Test Accuracy= 0.9232
# Step 3580, Minibatch Loss= 0.0001, Training Accuracy= 0.9878, Test Accuracy= 0.9110
# Step 3590, Minibatch Loss= 0.0001, Training Accuracy= 0.9921, Test Accuracy= 0.9265
# Step 3600, Minibatch Loss= 0.0001, Training Accuracy= 0.9879, Test Accuracy= 0.8857
# Step 3610, Minibatch Loss= 0.0000, Training Accuracy= 0.9934, Test Accuracy= 0.9086
# Step 3620, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9008
# Step 3630, Minibatch Loss= 0.0000, Training Accuracy= 0.9934, Test Accuracy= 0.9023
# Step 3640, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9140
# Step 3650, Minibatch Loss= 0.0000, Training Accuracy= 0.9946, Test Accuracy= 0.8972
# Step 3660, Minibatch Loss= 0.0001, Training Accuracy= 0.9912, Test Accuracy= 0.8989
# Step 3670, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.9139
# Step 3680, Minibatch Loss= 0.0001, Training Accuracy= 0.9895, Test Accuracy= 0.8964
# Step 3690, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.8889
# Step 3700, Minibatch Loss= 0.0001, Training Accuracy= 0.9909, Test Accuracy= 0.8922
# Step 3710, Minibatch Loss= 0.0001, Training Accuracy= 0.9916, Test Accuracy= 0.8935
# Step 3720, Minibatch Loss= 0.0000, Training Accuracy= 0.9936, Test Accuracy= 0.9075
# Step 3730, Minibatch Loss= 0.0000, Training Accuracy= 0.9933, Test Accuracy= 0.9143
# Step 3740, Minibatch Loss= 0.0002, Training Accuracy= 0.9863, Test Accuracy= 0.9153
# Step 3750, Minibatch Loss= 0.0002, Training Accuracy= 0.9862, Test Accuracy= 0.9164
# Step 3760, Minibatch Loss= 0.0001, Training Accuracy= 0.9892, Test Accuracy= 0.9016
# Step 3770, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.8827
# Step 3780, Minibatch Loss= 0.0001, Training Accuracy= 0.9920, Test Accuracy= 0.9216
# Step 3790, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9094
# Step 3800, Minibatch Loss= 0.0001, Training Accuracy= 0.9900, Test Accuracy= 0.9027
# Step 3810, Minibatch Loss= 0.0001, Training Accuracy= 0.9904, Test Accuracy= 0.8940
# Step 3820, Minibatch Loss= 0.0001, Training Accuracy= 0.9927, Test Accuracy= 0.8854
# Step 3830, Minibatch Loss= 0.0001, Training Accuracy= 0.9913, Test Accuracy= 0.8963
# Step 3840, Minibatch Loss= 0.0001, Training Accuracy= 0.9894, Test Accuracy= 0.8925
# Step 3850, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.8875
# Step 3860, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.9083
# Step 3870, Minibatch Loss= 0.0001, Training Accuracy= 0.9918, Test Accuracy= 0.9124
# Step 3880, Minibatch Loss= 0.0001, Training Accuracy= 0.9929, Test Accuracy= 0.9089
# Step 3890, Minibatch Loss= 0.0001, Training Accuracy= 0.9885, Test Accuracy= 0.8780
# Step 3900, Minibatch Loss= 0.0003, Training Accuracy= 0.9825, Test Accuracy= 0.8671
# Step 3910, Minibatch Loss= 0.0002, Training Accuracy= 0.9876, Test Accuracy= 0.8797
# Step 3920, Minibatch Loss= 0.0001, Training Accuracy= 0.9898, Test Accuracy= 0.8502
# Step 3930, Minibatch Loss= 0.0001, Training Accuracy= 0.9896, Test Accuracy= 0.8753
# Step 3940, Minibatch Loss= 0.0000, Training Accuracy= 0.9930, Test Accuracy= 0.8853
# Step 3950, Minibatch Loss= 0.0000, Training Accuracy= 0.9934, Test Accuracy= 0.9026
# Step 3960, Minibatch Loss= 0.0001, Training Accuracy= 0.9879, Test Accuracy= 0.8933
# Step 3970, Minibatch Loss= 0.0001, Training Accuracy= 0.9889, Test Accuracy= 0.8956
# Step 3980, Minibatch Loss= 0.0001, Training Accuracy= 0.9908, Test Accuracy= 0.8849
# Step 3990, Minibatch Loss= 0.0001, Training Accuracy= 0.9910, Test Accuracy= 0.8878
# Step 4000, Minibatch Loss= 0.0001, Training Accuracy= 0.9905, Test Accuracy= 0.8543

# %%
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    pred00 = session.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = session.run([prediction2], feed_dict={X: test_data, is_training: False})
    pred02 = session.run([prediction2], feed_dict={X: trainX.reshape(-1,look_back,1), is_training: False})

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred02).reshape(-1,1)[-200:])
plt.plot(np.array(trainX).reshape(-1,)[-200:],c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred01).reshape(-1,1))
plt.plot(np.array(testY).reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

x=list(range(0,len(pred00[0])))
y1=np.array(pred01).reshape(1,-1)[0]+2*np.std(np.array(pred01).reshape(1,-1))
y2=np.array(pred01).reshape(1,-1)[0]-2*np.std(np.array(pred01).reshape(1,-1))
fig, ax1 = plt.subplots(1, 1, sharex=True)
ax1.plot(np.array(pred01).reshape(1,-1)[0],'--',color='blue',alpha=0.5)
ax1.fill_between(x, y1, y2,color='blue',alpha=0.3)
ax1.plot(x,np.array(testY).reshape(-1,),c='red')
plt.xlabel('Days')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R2',r2_score(testY.reshape(1,-1)[0],np.array(pred01).reshape(1,-1)[0]))
# Out:
# R2 0.2855424415633445

# %%
x_test[-1]
# Out:
# array([[0.9508357 ],
#        [0.9512057 ],
#        [0.94692063],
#        [0.93898606]], dtype=float32)

# %%
x_test=testX[-1].reshape(-1,look_back,1)
prev=[]
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/model.ckpt"
    saver.restore(session, ckpt)
    for i in range(0,21):
        pred02 = session.run([prediction2], feed_dict={X: x_test, is_training: False})[0][0]
        prev.append(pred02)
        #print(pred02)
        x_test=np.concatenate([x_test[0][1:look_back],[pred02]],axis=0).reshape(-1,look_back,1)
        #print(x_test)

# %%
limit=8

# %%
np.array(testY)[0:limit].reshape(-1,)[-1]
# Out:
# 0.9128111

# %%
plt.plot(np.array(prev)[0:limit].reshape(-1,1))
#plt.plot(np.array(testY)[0:limit].reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()
#real=(np.array(testY)[0:limit].reshape(-1,)[-1]/np.array(testY)[0:limit].reshape(-1,)[0]-1)*100
prevista=(np.array(prev)[0:limit].reshape(-1,1)[-1]/np.array(prev)[0:limit].reshape(-1,1)[0]-1)*100
#print('Variação Real',"%.2f" % real + '%')
print('Variação Prevista',["%.2f" % prevista+'%'])
#print('Erro',["%.2f" % float((prevista-real))+'%'])
# Out:
# Variação Prevista ['-10.54%']
