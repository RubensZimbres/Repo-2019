# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
#pip install pandas-datareader

stock = 'LAME3.SA'
source = 'yahoo'

# Set date range (Google went public August 19, 2004)
start = datetime.datetime(2005, 8, 19)
end = datetime.datetime(2019, 8, 8)

# Collect Google stock data
goog_df = data.DataReader(stock, source, start, end)

dataset = goog_df['Adj Close']
print(len(dataset))
goog_df['Adj Close'].plot(kind='line', grid=True, title='GOOG Adjusted Closes, IPO through 2016')
# Out:
# 3462

# %%
goog_df['Adj Close'][-1]
# Out:
# 14.829999923706055

# %%
import tensorflow as tf
import pandas as pd  
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import tensorflow_probability as tfp


dataset = np.array(dataset.astype('float32')).reshape(-1,1)

def norm(x):
    return (x-np.min(x))/(np.max(x)-np.min(x))

#dataset=norm(dataset)

look_back=4
np.random.seed(7)
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.99)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))

def create_dataset(dataset, look_back=look_back):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX

trainY = trainY.reshape(len(trainY), 1)
testY = testY.reshape(len(testY), 1)
trainY

X0=trainX
Y0=trainY
# Out:
# 3427 35

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
tfd = tfp.distributions

class TemporalConvNet(tf.layers.Layer):
    def __init__(self, num_channels, kernel_size=2, dropout=0.2,
                 trainable=False, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalConvNet, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )
        self.layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            out_channels = num_channels[i]
            self.layers.append(
                TemporalBlock(out_channels, kernel_size, strides=1, dilation_rate=dilation_size,
                              dropout=dropout, name="tblock_{}".format(i))
            )
    
    def call(self, inputs, training=False):
        outputs = inputs
        for layer in self.layers:
            outputs = layer(outputs, training=training)
        return outputs

learning_rate = 0.001
display_step = 10
num_input = 1
num_hidden = 35
num_classes = 1

dropout = 0
kernel_size = 8
levels = 6

class CausalConv1D(tf.layers.Conv1D):
    def __init__(self, filters,
               kernel_size,
               strides=1,
               dilation_rate=1,
               activation=None,
               use_bias=True,
               kernel_initializer=None,
               bias_initializer=tf.zeros_initializer(),
               kernel_regularizer=None,
               bias_regularizer=None,
               activity_regularizer=None,
               kernel_constraint=None,
               bias_constraint=None,
               trainable=False,
               name=None,
               **kwargs):
        super(CausalConv1D, self).__init__(
            filters=filters,
            kernel_size=kernel_size,
            strides=strides,
            padding='valid',
            data_format='channels_last',
            dilation_rate=dilation_rate,
            activation=activation,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
            activity_regularizer=activity_regularizer,
            kernel_constraint=kernel_constraint,
            bias_constraint=bias_constraint,
            trainable=trainable,
            name=name, **kwargs
        )
       
    def call(self, inputs):
        padding = (self.kernel_size[0] - 1) * self.dilation_rate[0]
        inputs = tf.pad(inputs, tf.constant([(0, 0,), (1, 0), (0, 0)]) * padding)
        return super(CausalConv1D, self).call(inputs)



class TemporalBlock(tf.layers.Layer):
    def __init__(self, n_outputs, kernel_size, strides, dilation_rate, dropout=0.2, 
                 trainable=False, name=None, dtype=None, 
                 activity_regularizer=None, **kwargs):
        super(TemporalBlock, self).__init__(
            trainable=trainable, dtype=dtype,
            activity_regularizer=activity_regularizer,
            name=name, **kwargs
        )        
        self.dropout = dropout
        self.n_outputs = n_outputs
        self.conv1 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv1")
        self.conv2 = CausalConv1D(
            n_outputs, kernel_size, strides=strides, 
            dilation_rate=dilation_rate, activation=tf.nn.relu, 
            name="conv2")
        self.down_sample = None

    
    def build(self, input_shape):
        channel_dim = 2
        self.dropout1 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        self.dropout2 = tf.layers.Dropout(self.dropout, [tf.constant(1), tf.constant(1), tf.constant(self.n_outputs)])
        if input_shape[channel_dim] != self.n_outputs:
            self.down_sample = tf.layers.Dense(self.n_outputs, activation=None)
    
    def call(self, inputs, training=False):
        x = self.conv1(inputs)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout1(x, training=training)
        x = self.conv2(x)
        x = tf.contrib.layers.layer_norm(x)
        x = self.dropout2(x, training=training)
        #x = tfp.layers.DistributionLambda(make_distribution_fn=lambda t: tfd.Normal(loc=t, scale=1))(x)
        #x = tf.contrib.layers.layer_norm(x)
        #x = tf.layers.dense(inputs=x,units=3)
        if self.down_sample is not None:
          inputs = self.down_sample(inputs)
        return tf.nn.relu(x)



tf.reset_default_graph()
graph = tf.Graph()
with graph.as_default():
    tf.set_random_seed(2)
    
    X = tf.placeholder("float", [None, look_back,1])
    Y = tf.placeholder("float", [None, num_classes])
    is_training = tf.placeholder("bool")
    
    logits = tf.layers.dense(
        TemporalConvNet([num_hidden] * levels, kernel_size, dropout)(
            X, training=is_training),
        num_classes, activation=None, 
        kernel_initializer=tf.glorot_uniform_initializer()
    )
    print(logits)

    mm,_=tf.nn.moments(tf.reshape(tf.nn.relu(logits),[-1,look_back]),axes=[1])
    prediction=tf.nn.relu(logits)
    
    prediction2 = tf.reshape(tf.cast(mm,tf.float32),[-1,1])
    
    loss_op = tf.reduce_mean(tf.losses.mean_squared_error(
        labels=Y,predictions=prediction2))
    
    accuracy=1-tf.sqrt(loss_op)

    optimizer = tf.train.AdamOptimizer(learning_rate=0.0001)
    train_op = optimizer.minimize(loss_op)


    saver = tf.train.Saver()
    print("All parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.global_variables()]))
    print("Trainable parameters:", np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()]))

def next_batch(num, data, labels):
    idx = np.arange(0 , len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    return np.asarray(data_shuffle).astype(np.float32), np.asarray(labels_shuffle).astype(np.float32)

log_dir = "/home/rubensvectomobile/BOVESPA/"
tb_writer = tf.summary.FileWriter(log_dir, graph)
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.7
best_val_acc = 0.93

training_epochs = 8000
batch_size = int(trainX.shape[0]/4)


X0=X0.reshape(-1,look_back,1)
testX=testX.reshape(-1,look_back,1)
# Out:
# Tensor("dense/BiasAdd:0", shape=(?, 4, 1), dtype=float32)
# All parameters: 111200.0
# Trainable parameters: 946

# %%
with tf.Session(graph=graph, config=config) as sess:
    #init = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
    #sess.run(init)
    ckpt = "/home/rubensvectomobile/BOVESPA/real/model.ckpt"
    saver.restore(sess, ckpt)

    for step in range(1, training_epochs+1):
        Xt, Yt = next_batch(batch_size, X0, Y0)
        batch_x, batch_y = Xt,Yt
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y, is_training: True})
        if step % display_step == 0 or step == 1:
            loss, acc = sess.run([loss_op, accuracy], feed_dict={
                X: batch_x, Y: batch_y, is_training: False})
            test_data = testX
            test_label = testY
            val_acc = sess.run(accuracy, feed_dict={X: test_data, Y: test_label, is_training: False})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.4f}".format(acc) + ", Test Accuracy= " + \
                  "{:.4f}".format(val_acc))
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                save_path = saver.save(sess, "/home/rubensvectomobile/BOVESPA/real/model.ckpt")
                print("Model saved in path: %s" % save_path)
    pred00 = sess.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = sess.run([prediction2], feed_dict={X: test_data, is_training: False})
# Out:
# Step 1, Minibatch Loss= 0.0004, Training Accuracy= 0.9808, Test Accuracy= 0.9709
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 10, Minibatch Loss= 0.0004, Training Accuracy= 0.9813, Test Accuracy= 0.9715
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 20, Minibatch Loss= 0.0003, Training Accuracy= 0.9822, Test Accuracy= 0.9722
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 30, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9726
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 40, Minibatch Loss= 0.0003, Training Accuracy= 0.9822, Test Accuracy= 0.9729
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 50, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.9734
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 60, Minibatch Loss= 0.0004, Training Accuracy= 0.9804, Test Accuracy= 0.9739
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 70, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.9727
# Step 80, Minibatch Loss= 0.0003, Training Accuracy= 0.9820, Test Accuracy= 0.9748
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 90, Minibatch Loss= 0.0003, Training Accuracy= 0.9833, Test Accuracy= 0.9745
# Step 100, Minibatch Loss= 0.0003, Training Accuracy= 0.9819, Test Accuracy= 0.9739
# Step 110, Minibatch Loss= 0.0003, Training Accuracy= 0.9836, Test Accuracy= 0.9736
# Step 120, Minibatch Loss= 0.0003, Training Accuracy= 0.9818, Test Accuracy= 0.9745
# Step 130, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9750
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 140, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9747
# Step 150, Minibatch Loss= 0.0003, Training Accuracy= 0.9820, Test Accuracy= 0.9746
# Step 160, Minibatch Loss= 0.0003, Training Accuracy= 0.9826, Test Accuracy= 0.9747
# Step 170, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9742
# Step 180, Minibatch Loss= 0.0003, Training Accuracy= 0.9833, Test Accuracy= 0.9746
# Step 190, Minibatch Loss= 0.0003, Training Accuracy= 0.9819, Test Accuracy= 0.9742
# Step 200, Minibatch Loss= 0.0003, Training Accuracy= 0.9821, Test Accuracy= 0.9744
# Step 210, Minibatch Loss= 0.0003, Training Accuracy= 0.9821, Test Accuracy= 0.9741
# Step 220, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9754
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 230, Minibatch Loss= 0.0003, Training Accuracy= 0.9821, Test Accuracy= 0.9748
# Step 240, Minibatch Loss= 0.0003, Training Accuracy= 0.9828, Test Accuracy= 0.9749
# Step 250, Minibatch Loss= 0.0003, Training Accuracy= 0.9828, Test Accuracy= 0.9747
# Step 260, Minibatch Loss= 0.0003, Training Accuracy= 0.9821, Test Accuracy= 0.9751
# Step 270, Minibatch Loss= 0.0003, Training Accuracy= 0.9827, Test Accuracy= 0.9747
# Step 280, Minibatch Loss= 0.0003, Training Accuracy= 0.9826, Test Accuracy= 0.9742
# Step 290, Minibatch Loss= 0.0003, Training Accuracy= 0.9824, Test Accuracy= 0.9746
# Step 300, Minibatch Loss= 0.0003, Training Accuracy= 0.9828, Test Accuracy= 0.9731
# Step 310, Minibatch Loss= 0.0003, Training Accuracy= 0.9823, Test Accuracy= 0.9746
# Step 320, Minibatch Loss= 0.0003, Training Accuracy= 0.9823, Test Accuracy= 0.9748
# Step 330, Minibatch Loss= 0.0003, Training Accuracy= 0.9834, Test Accuracy= 0.9749
# Step 340, Minibatch Loss= 0.0003, Training Accuracy= 0.9836, Test Accuracy= 0.9756
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 350, Minibatch Loss= 0.0003, Training Accuracy= 0.9819, Test Accuracy= 0.9749
# Step 360, Minibatch Loss= 0.0003, Training Accuracy= 0.9833, Test Accuracy= 0.9742
# Step 370, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9750
# Step 380, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9739
# Step 390, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9745
# Step 400, Minibatch Loss= 0.0003, Training Accuracy= 0.9821, Test Accuracy= 0.9749
# Step 410, Minibatch Loss= 0.0003, Training Accuracy= 0.9818, Test Accuracy= 0.9758
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 420, Minibatch Loss= 0.0003, Training Accuracy= 0.9825, Test Accuracy= 0.9756
# Step 430, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9751
# Step 440, Minibatch Loss= 0.0003, Training Accuracy= 0.9821, Test Accuracy= 0.9742
# Step 450, Minibatch Loss= 0.0003, Training Accuracy= 0.9821, Test Accuracy= 0.9743
# Step 460, Minibatch Loss= 0.0003, Training Accuracy= 0.9834, Test Accuracy= 0.9747
# Step 470, Minibatch Loss= 0.0003, Training Accuracy= 0.9822, Test Accuracy= 0.9745
# Step 480, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9742
# Step 490, Minibatch Loss= 0.0003, Training Accuracy= 0.9821, Test Accuracy= 0.9747
# Step 500, Minibatch Loss= 0.0003, Training Accuracy= 0.9834, Test Accuracy= 0.9749
# Step 510, Minibatch Loss= 0.0003, Training Accuracy= 0.9825, Test Accuracy= 0.9746
# Step 520, Minibatch Loss= 0.0003, Training Accuracy= 0.9820, Test Accuracy= 0.9745
# Step 530, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9744
# Step 540, Minibatch Loss= 0.0003, Training Accuracy= 0.9825, Test Accuracy= 0.9748
# Step 550, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9745
# Step 560, Minibatch Loss= 0.0003, Training Accuracy= 0.9827, Test Accuracy= 0.9747
# Step 570, Minibatch Loss= 0.0003, Training Accuracy= 0.9835, Test Accuracy= 0.9750
# Step 580, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9749
# Step 590, Minibatch Loss= 0.0003, Training Accuracy= 0.9825, Test Accuracy= 0.9738
# Step 600, Minibatch Loss= 0.0003, Training Accuracy= 0.9833, Test Accuracy= 0.9752
# Step 610, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9743
# Step 620, Minibatch Loss= 0.0003, Training Accuracy= 0.9828, Test Accuracy= 0.9744
# Step 630, Minibatch Loss= 0.0003, Training Accuracy= 0.9833, Test Accuracy= 0.9754
# Step 640, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.9745
# Step 650, Minibatch Loss= 0.0004, Training Accuracy= 0.9808, Test Accuracy= 0.9742
# Step 660, Minibatch Loss= 0.0003, Training Accuracy= 0.9818, Test Accuracy= 0.9749
# Step 670, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9740
# Step 680, Minibatch Loss= 0.0003, Training Accuracy= 0.9825, Test Accuracy= 0.9742
# Step 690, Minibatch Loss= 0.0003, Training Accuracy= 0.9833, Test Accuracy= 0.9749
# Step 700, Minibatch Loss= 0.0003, Training Accuracy= 0.9827, Test Accuracy= 0.9741
# Step 710, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.9750
# Step 720, Minibatch Loss= 0.0003, Training Accuracy= 0.9826, Test Accuracy= 0.9756
# Step 730, Minibatch Loss= 0.0003, Training Accuracy= 0.9820, Test Accuracy= 0.9751
# Step 740, Minibatch Loss= 0.0003, Training Accuracy= 0.9828, Test Accuracy= 0.9741
# Step 750, Minibatch Loss= 0.0002, Training Accuracy= 0.9843, Test Accuracy= 0.9757
# Step 760, Minibatch Loss= 0.0003, Training Accuracy= 0.9819, Test Accuracy= 0.9744
# Step 770, Minibatch Loss= 0.0003, Training Accuracy= 0.9828, Test Accuracy= 0.9751
# Step 780, Minibatch Loss= 0.0003, Training Accuracy= 0.9834, Test Accuracy= 0.9752
# Step 790, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9744
# Step 800, Minibatch Loss= 0.0003, Training Accuracy= 0.9827, Test Accuracy= 0.9746
# Step 810, Minibatch Loss= 0.0003, Training Accuracy= 0.9820, Test Accuracy= 0.9753
# Step 820, Minibatch Loss= 0.0004, Training Accuracy= 0.9808, Test Accuracy= 0.9744
# Step 830, Minibatch Loss= 0.0003, Training Accuracy= 0.9828, Test Accuracy= 0.9753
# Step 840, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9754
# Step 850, Minibatch Loss= 0.0003, Training Accuracy= 0.9837, Test Accuracy= 0.9731
# Step 860, Minibatch Loss= 0.0003, Training Accuracy= 0.9827, Test Accuracy= 0.9752
# Step 870, Minibatch Loss= 0.0003, Training Accuracy= 0.9822, Test Accuracy= 0.9756
# Step 880, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9751
# Step 890, Minibatch Loss= 0.0003, Training Accuracy= 0.9825, Test Accuracy= 0.9752
# Step 900, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9753
# Step 910, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9756
# Step 920, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9752
# Step 930, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9743
# Step 940, Minibatch Loss= 0.0003, Training Accuracy= 0.9823, Test Accuracy= 0.9756
# Step 950, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.9742
# Step 960, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9750
# Step 970, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9745
# Step 980, Minibatch Loss= 0.0003, Training Accuracy= 0.9827, Test Accuracy= 0.9749
# Step 990, Minibatch Loss= 0.0003, Training Accuracy= 0.9824, Test Accuracy= 0.9751
# Step 1000, Minibatch Loss= 0.0003, Training Accuracy= 0.9826, Test Accuracy= 0.9758
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1010, Minibatch Loss= 0.0003, Training Accuracy= 0.9817, Test Accuracy= 0.9752
# Step 1020, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9744
# Step 1030, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9749
# Step 1040, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9747
# Step 1050, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.9760
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1060, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9760
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1070, Minibatch Loss= 0.0003, Training Accuracy= 0.9835, Test Accuracy= 0.9749
# Step 1080, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.9751
# Step 1090, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9754
# Step 1100, Minibatch Loss= 0.0003, Training Accuracy= 0.9834, Test Accuracy= 0.9750
# Step 1110, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.9747
# Step 1120, Minibatch Loss= 0.0002, Training Accuracy= 0.9842, Test Accuracy= 0.9757
# Step 1130, Minibatch Loss= 0.0002, Training Accuracy= 0.9842, Test Accuracy= 0.9758
# Step 1140, Minibatch Loss= 0.0003, Training Accuracy= 0.9834, Test Accuracy= 0.9750
# Step 1150, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9749
# Step 1160, Minibatch Loss= 0.0003, Training Accuracy= 0.9826, Test Accuracy= 0.9756
# Step 1170, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9753
# Step 1180, Minibatch Loss= 0.0003, Training Accuracy= 0.9837, Test Accuracy= 0.9749
# Step 1190, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9758
# Step 1200, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9758
# Step 1210, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9759
# Step 1220, Minibatch Loss= 0.0003, Training Accuracy= 0.9841, Test Accuracy= 0.9764
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1230, Minibatch Loss= 0.0003, Training Accuracy= 0.9830, Test Accuracy= 0.9762
# Step 1240, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9767
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1250, Minibatch Loss= 0.0003, Training Accuracy= 0.9837, Test Accuracy= 0.9774
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1260, Minibatch Loss= 0.0003, Training Accuracy= 0.9838, Test Accuracy= 0.9776
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1270, Minibatch Loss= 0.0002, Training Accuracy= 0.9842, Test Accuracy= 0.9777
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1280, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9786
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1290, Minibatch Loss= 0.0002, Training Accuracy= 0.9850, Test Accuracy= 0.9787
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1300, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9786
# Step 1310, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9783
# Step 1320, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9784
# Step 1330, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9789
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1340, Minibatch Loss= 0.0003, Training Accuracy= 0.9841, Test Accuracy= 0.9790
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1350, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9790
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1360, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9790
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1370, Minibatch Loss= 0.0002, Training Accuracy= 0.9842, Test Accuracy= 0.9789
# Step 1380, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9788
# Step 1390, Minibatch Loss= 0.0003, Training Accuracy= 0.9829, Test Accuracy= 0.9791
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1400, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9787
# Step 1410, Minibatch Loss= 0.0002, Training Accuracy= 0.9843, Test Accuracy= 0.9788
# Step 1420, Minibatch Loss= 0.0003, Training Accuracy= 0.9835, Test Accuracy= 0.9791
# Step 1430, Minibatch Loss= 0.0003, Training Accuracy= 0.9836, Test Accuracy= 0.9792
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1440, Minibatch Loss= 0.0003, Training Accuracy= 0.9833, Test Accuracy= 0.9785
# Step 1450, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9782
# Step 1460, Minibatch Loss= 0.0002, Training Accuracy= 0.9843, Test Accuracy= 0.9787
# Step 1470, Minibatch Loss= 0.0003, Training Accuracy= 0.9834, Test Accuracy= 0.9791
# Step 1480, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9789
# Step 1490, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.9788
# Step 1500, Minibatch Loss= 0.0003, Training Accuracy= 0.9840, Test Accuracy= 0.9791
# Step 1510, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9789
# Step 1520, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9783
# Step 1530, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9789
# Step 1540, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9790
# Step 1550, Minibatch Loss= 0.0003, Training Accuracy= 0.9841, Test Accuracy= 0.9778
# Step 1560, Minibatch Loss= 0.0002, Training Accuracy= 0.9843, Test Accuracy= 0.9787
# Step 1570, Minibatch Loss= 0.0003, Training Accuracy= 0.9828, Test Accuracy= 0.9786
# Step 1580, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.9787
# Step 1590, Minibatch Loss= 0.0003, Training Accuracy= 0.9838, Test Accuracy= 0.9791
# Step 1600, Minibatch Loss= 0.0003, Training Accuracy= 0.9835, Test Accuracy= 0.9782
# Step 1610, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.9788
# Step 1620, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9792
# Step 1630, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9787
# Step 1640, Minibatch Loss= 0.0003, Training Accuracy= 0.9842, Test Accuracy= 0.9791
# Step 1650, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9788
# Step 1660, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.9791
# Step 1670, Minibatch Loss= 0.0002, Training Accuracy= 0.9846, Test Accuracy= 0.9786
# Step 1680, Minibatch Loss= 0.0003, Training Accuracy= 0.9842, Test Accuracy= 0.9782
# Step 1690, Minibatch Loss= 0.0003, Training Accuracy= 0.9828, Test Accuracy= 0.9788
# Step 1700, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9787
# Step 1710, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9788
# Step 1720, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9790
# Step 1730, Minibatch Loss= 0.0003, Training Accuracy= 0.9838, Test Accuracy= 0.9788
# Step 1740, Minibatch Loss= 0.0003, Training Accuracy= 0.9842, Test Accuracy= 0.9783
# Step 1750, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9784
# Step 1760, Minibatch Loss= 0.0003, Training Accuracy= 0.9838, Test Accuracy= 0.9792
# Step 1770, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9783
# Step 1780, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9789
# Step 1790, Minibatch Loss= 0.0003, Training Accuracy= 0.9840, Test Accuracy= 0.9789
# Step 1800, Minibatch Loss= 0.0003, Training Accuracy= 0.9835, Test Accuracy= 0.9786
# Step 1810, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.9786
# Step 1820, Minibatch Loss= 0.0003, Training Accuracy= 0.9831, Test Accuracy= 0.9792
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1830, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9785
# Step 1840, Minibatch Loss= 0.0003, Training Accuracy= 0.9837, Test Accuracy= 0.9787
# Step 1850, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9785
# Step 1860, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9791
# Step 1870, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9792
# Step 1880, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.9789
# Step 1890, Minibatch Loss= 0.0003, Training Accuracy= 0.9840, Test Accuracy= 0.9789
# Step 1900, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9783
# Step 1910, Minibatch Loss= 0.0003, Training Accuracy= 0.9842, Test Accuracy= 0.9793
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 1920, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9792
# Step 1930, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9792
# Step 1940, Minibatch Loss= 0.0003, Training Accuracy= 0.9832, Test Accuracy= 0.9786
# Step 1950, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9781
# Step 1960, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.9790
# Step 1970, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9792
# Step 1980, Minibatch Loss= 0.0002, Training Accuracy= 0.9843, Test Accuracy= 0.9791
# Step 1990, Minibatch Loss= 0.0003, Training Accuracy= 0.9835, Test Accuracy= 0.9782
# Step 2000, Minibatch Loss= 0.0003, Training Accuracy= 0.9839, Test Accuracy= 0.9794
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 2010, Minibatch Loss= 0.0002, Training Accuracy= 0.9846, Test Accuracy= 0.9792
# Step 2020, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9789
# Step 2030, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9789
# Step 2040, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9794
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 2050, Minibatch Loss= 0.0003, Training Accuracy= 0.9837, Test Accuracy= 0.9787
# Step 2060, Minibatch Loss= 0.0002, Training Accuracy= 0.9843, Test Accuracy= 0.9785
# Step 2070, Minibatch Loss= 0.0002, Training Accuracy= 0.9853, Test Accuracy= 0.9794
# Step 2080, Minibatch Loss= 0.0002, Training Accuracy= 0.9845, Test Accuracy= 0.9790
# Step 2090, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9786
# Step 2100, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.
Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9801
# Step 6780, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9802
# Step 6790, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9795
# Step 6800, Minibatch Loss= 0.0002, Training Accuracy= 0.9854, Test Accuracy= 0.9793
# Step 6810, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9805
# Step 6820, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9802
# Step 6830, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9799
# Step 6840, Minibatch Loss= 0.0003, Training Accuracy= 0.9840, Test Accuracy= 0.9803
# Step 6850, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9790
# Step 6860, Minibatch Loss= 0.0002, Training Accuracy= 0.9862, Test Accuracy= 0.9808
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 6870, Minibatch Loss= 0.0002, Training Accuracy= 0.9858, Test Accuracy= 0.9796
# Step 6880, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9798
# Step 6890, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9808
# Step 6900, Minibatch Loss= 0.0002, Training Accuracy= 0.9862, Test Accuracy= 0.9798
# Step 6910, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9796
# Step 6920, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9806
# Step 6930, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9797
# Step 6940, Minibatch Loss= 0.0002, Training Accuracy= 0.9862, Test Accuracy= 0.9807
# Step 6950, Minibatch Loss= 0.0002, Training Accuracy= 0.9863, Test Accuracy= 0.9801
# Step 6960, Minibatch Loss= 0.0002, Training Accuracy= 0.9864, Test Accuracy= 0.9802
# Step 6970, Minibatch Loss= 0.0002, Training Accuracy= 0.9854, Test Accuracy= 0.9806
# Step 6980, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9798
# Step 6990, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9797
# Step 7000, Minibatch Loss= 0.0002, Training Accuracy= 0.9861, Test Accuracy= 0.9808
# Step 7010, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9798
# Step 7020, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9794
# Step 7030, Minibatch Loss= 0.0002, Training Accuracy= 0.9861, Test Accuracy= 0.9802
# Step 7040, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9807
# Step 7050, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9791
# Step 7060, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9803
# Step 7070, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.9800
# Step 7080, Minibatch Loss= 0.0002, Training Accuracy= 0.9854, Test Accuracy= 0.9805
# Step 7090, Minibatch Loss= 0.0002, Training Accuracy= 0.9860, Test Accuracy= 0.9804
# Step 7100, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9794
# Step 7110, Minibatch Loss= 0.0002, Training Accuracy= 0.9866, Test Accuracy= 0.9801
# Step 7120, Minibatch Loss= 0.0002, Training Accuracy= 0.9868, Test Accuracy= 0.9805
# Step 7130, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9802
# Step 7140, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9798
# Step 7150, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9797
# Step 7160, Minibatch Loss= 0.0002, Training Accuracy= 0.9850, Test Accuracy= 0.9804
# Step 7170, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9799
# Step 7180, Minibatch Loss= 0.0002, Training Accuracy= 0.9860, Test Accuracy= 0.9808
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 7190, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9794
# Step 7200, Minibatch Loss= 0.0002, Training Accuracy= 0.9862, Test Accuracy= 0.9804
# Step 7210, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9801
# Step 7220, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9804
# Step 7230, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9807
# Step 7240, Minibatch Loss= 0.0002, Training Accuracy= 0.9848, Test Accuracy= 0.9787
# Step 7250, Minibatch Loss= 0.0002, Training Accuracy= 0.9850, Test Accuracy= 0.9802
# Step 7260, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9804
# Step 7270, Minibatch Loss= 0.0002, Training Accuracy= 0.9871, Test Accuracy= 0.9803
# Step 7280, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9804
# Step 7290, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.9789
# Step 7300, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9806
# Step 7310, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9804
# Step 7320, Minibatch Loss= 0.0002, Training Accuracy= 0.9862, Test Accuracy= 0.9805
# Step 7330, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.9801
# Step 7340, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9801
# Step 7350, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9801
# Step 7360, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9808
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 7370, Minibatch Loss= 0.0002, Training Accuracy= 0.9862, Test Accuracy= 0.9800
# Step 7380, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9794
# Step 7390, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9809
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 7400, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9803
# Step 7410, Minibatch Loss= 0.0002, Training Accuracy= 0.9861, Test Accuracy= 0.9805
# Step 7420, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9807
# Step 7430, Minibatch Loss= 0.0002, Training Accuracy= 0.9854, Test Accuracy= 0.9803
# Step 7440, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9802
# Step 7450, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9805
# Step 7460, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9794
# Step 7470, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9807
# Step 7480, Minibatch Loss= 0.0002, Training Accuracy= 0.9864, Test Accuracy= 0.9799
# Step 7490, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9800
# Step 7500, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.9808
# Step 7510, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9800
# Step 7520, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9799
# Step 7530, Minibatch Loss= 0.0002, Training Accuracy= 0.9869, Test Accuracy= 0.9806
# Step 7540, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9805
# Step 7550, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9799
# Step 7560, Minibatch Loss= 0.0002, Training Accuracy= 0.9860, Test Accuracy= 0.9800
# Step 7570, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9804
# Step 7580, Minibatch Loss= 0.0002, Training Accuracy= 0.9861, Test Accuracy= 0.9806
# Step 7590, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9797
# Step 7600, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9801
# Step 7610, Minibatch Loss= 0.0002, Training Accuracy= 0.9863, Test Accuracy= 0.9808
# Step 7620, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9802
# Step 7630, Minibatch Loss= 0.0002, Training Accuracy= 0.9858, Test Accuracy= 0.9804
# Step 7640, Minibatch Loss= 0.0002, Training Accuracy= 0.9844, Test Accuracy= 0.9804
# Step 7650, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9807
# Step 7660, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.9806
# Step 7670, Minibatch Loss= 0.0002, Training Accuracy= 0.9869, Test Accuracy= 0.9800
# Step 7680, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9807
# Step 7690, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9797
# Step 7700, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9796
# Step 7710, Minibatch Loss= 0.0002, Training Accuracy= 0.9850, Test Accuracy= 0.9805
# Step 7720, Minibatch Loss= 0.0002, Training Accuracy= 0.9861, Test Accuracy= 0.9801
# Step 7730, Minibatch Loss= 0.0002, Training Accuracy= 0.9853, Test Accuracy= 0.9807
# Step 7740, Minibatch Loss= 0.0003, Training Accuracy= 0.9840, Test Accuracy= 0.9803
# Step 7750, Minibatch Loss= 0.0002, Training Accuracy= 0.9850, Test Accuracy= 0.9804
# Step 7760, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.9804
# Step 7770, Minibatch Loss= 0.0003, Training Accuracy= 0.9836, Test Accuracy= 0.9792
# Step 7780, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9803
# Step 7790, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9805
# Step 7800, Minibatch Loss= 0.0002, Training Accuracy= 0.9862, Test Accuracy= 0.9808
# Step 7810, Minibatch Loss= 0.0002, Training Accuracy= 0.9851, Test Accuracy= 0.9805
# Step 7820, Minibatch Loss= 0.0002, Training Accuracy= 0.9865, Test Accuracy= 0.9803
# Step 7830, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9801
# Step 7840, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9805
# Step 7850, Minibatch Loss= 0.0002, Training Accuracy= 0.9855, Test Accuracy= 0.9803
# Step 7860, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9806
# Step 7870, Minibatch Loss= 0.0002, Training Accuracy= 0.9866, Test Accuracy= 0.9794
# Step 7880, Minibatch Loss= 0.0002, Training Accuracy= 0.9859, Test Accuracy= 0.9809
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 7890, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9802
# Step 7900, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9801
# Step 7910, Minibatch Loss= 0.0002, Training Accuracy= 0.9852, Test Accuracy= 0.9798
# Step 7920, Minibatch Loss= 0.0002, Training Accuracy= 0.9847, Test Accuracy= 0.9810
# Model saved in path: /home/rubensvectomobile/BOVESPA/real/model.ckpt
# Step 7930, Minibatch Loss= 0.0002, Training Accuracy= 0.9866, Test Accuracy= 0.9801
# Step 7940, Minibatch Loss= 0.0002, Training Accuracy= 0.9849, Test Accuracy= 0.9795
# Step 7950, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9804
# Step 7960, Minibatch Loss= 0.0002, Training Accuracy= 0.9854, Test Accuracy= 0.9802
# Step 7970, Minibatch Loss= 0.0002, Training Accuracy= 0.9857, Test Accuracy= 0.9799
# Step 7980, Minibatch Loss= 0.0002, Training Accuracy= 0.9856, Test Accuracy= 0.9803
# Step 7990, Minibatch Loss= 0.0002, Training Accuracy= 0.9873, Test Accuracy= 0.9801
# Step 8000, Minibatch Loss= 0.0002, Training Accuracy= 0.9863, Test Accuracy= 0.9801

# %%
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/real/model.ckpt"
    saver.restore(session, ckpt)
    pred00 = session.run([prediction], feed_dict={X: test_data, is_training: False})
    pred01 = session.run([prediction2], feed_dict={X: test_data, is_training: False})
    pred02 = session.run([prediction2], feed_dict={X: trainX.reshape(-1,look_back,1), is_training: False})
# Out:
# W0809 19:30:58.291533 140622298318592 deprecation.py:323] From /home/rubensvectomobile_gmail_com/.local/lib/python3.5/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred02).reshape(-1,1)[-200:])
plt.plot(np.array(trainX).reshape(-1,)[-200:],c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(np.array(pred01).reshape(-1,1))
plt.plot(np.array(testY).reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()

x=list(range(0,len(pred00[0])))
y1=np.array(pred01).reshape(1,-1)[0]+2*np.std(np.array(pred01).reshape(1,-1))
y2=np.array(pred01).reshape(1,-1)[0]-2*np.std(np.array(pred01).reshape(1,-1))
fig, ax1 = plt.subplots(1, 1, sharex=True)
ax1.plot(np.array(pred01).reshape(1,-1)[0],'--',color='blue',alpha=0.5)
ax1.fill_between(x, y1, y2,color='blue',alpha=0.3)
ax1.plot(x,np.array(testY).reshape(-1,),c='red')
plt.xlabel('Days')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R2',r2_score(testY.reshape(1,-1)[0],np.array(pred01).reshape(1,-1)[0]))
# Out:
# R2 0.8461312586213721

# %%
limit=8

# %%
x_test=testX[0].reshape(-1,look_back,1)
prev=[]
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/real/model.ckpt"
    saver.restore(session, ckpt)
    for i in range(0,21):
        pred02 = session.run([prediction2], feed_dict={X: x_test, is_training: False})[0][0]
        prev.append(pred02)
        #print(pred02)
        x_test=np.concatenate([x_test[0][1:look_back],[pred02]],axis=0).reshape(-1,look_back,1)
        #print(x_test)
        
plt.plot(np.array(prev)[0:limit].reshape(-1,1))
plt.plot(np.array(testY)[0:limit].reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()
real=(np.array(testY)[0:limit].reshape(-1,)[-1]/np.array(testY)[0:limit].reshape(-1,)[0]-1)*100
prevista=(np.array(prev)[0:limit].reshape(-1,1)[-1]/np.array(prev)[0:limit].reshape(-1,1)[0]-1)*100
print('Variação Real',"%.2f" % real + '%')
print('Variação Prevista',["%.2f" % prevista+'%'])
print('Erro',["%.2f" % float((prevista-real))+'%'])
# Out:
# Variação Real -2.79%
# Variação Prevista ['-1.41%']
# Erro ['1.38%']

# %%
x_test=testX[-1].reshape(-1,look_back,1)
prev=[]
with tf.Session(graph=graph, config=config) as session:
    ckpt = "/home/rubensvectomobile/BOVESPA/real/model.ckpt"
    saver.restore(session, ckpt)
    for i in range(0,21):
        pred02 = session.run([prediction2], feed_dict={X: x_test, is_training: False})[0][0]
        prev.append(pred02)
        #print(pred02)
        x_test=np.concatenate([x_test[0][1:look_back],[pred02]],axis=0).reshape(-1,look_back,1)
        #print(x_test)

# %%
limit=8

# %%
np.array(testY)[0:limit].reshape(-1,)[-1]
# Out:
# 0.7820822

# %%
plt.plot(np.array(prev)[0:limit].reshape(-1,1))
#plt.plot(np.array(testY)[0:limit].reshape(-1,),c='black')
plt.xlabel('Days')
plt.ylabel('Stock Price')
plt.show()
#real=(np.array(testY)[0:limit].reshape(-1,)[-1]/np.array(testY)[0:limit].reshape(-1,)[0]-1)*100
prevista=(np.array(prev)[0:limit].reshape(-1,1)[-1]/np.array(prev)[0:limit].reshape(-1,1)[0]-1)*100
#print('Variação Real',"%.2f" % real + '%')
print('Variação Prevista',["%.2f" % prevista+'%'])
#print('Erro',["%.2f" % float((prevista-real))+'%'])
# Out:
# Variação Prevista ['-4.12%']

# %%
import os
from pprint import pprint
import tensorflow as tf

tf_path = os.path.abspath('/home/rubensvectomobile/BOVESPA/real/model.ckpt')  # Path to our TensorFlow checkpoint
tf_vars = tf.train.list_variables(tf_path)
pprint(tf_vars)
# Out:
# [('beta1_power', []),
#  ('beta2_power', []),
#  ('dense/bias', [1]),
#  ('dense/bias/Adam', [1]),
#  ('dense/bias/Adam_1', [1]),
#  ('dense/kernel', [35, 1]),
#  ('dense/kernel/Adam', [35, 1]),
#  ('dense/kernel/Adam_1', [35, 1]),
#  ('temporal_conv_net/tblock_0/LayerNorm/beta', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm/gamma', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm_1/beta', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm_1/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm_1/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm_1/gamma', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm_1/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_0/LayerNorm_1/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_0/conv1/bias', [35]),
#  ('temporal_conv_net/tblock_0/conv1/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_0/conv1/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_0/conv1/kernel', [8, 1, 35]),
#  ('temporal_conv_net/tblock_0/conv1/kernel/Adam', [8, 1, 35]),
#  ('temporal_conv_net/tblock_0/conv1/kernel/Adam_1', [8, 1, 35]),
#  ('temporal_conv_net/tblock_0/conv2/bias', [35]),
#  ('temporal_conv_net/tblock_0/conv2/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_0/conv2/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_0/conv2/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_0/conv2/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_0/conv2/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_0/dense/bias', [35]),
#  ('temporal_conv_net/tblock_0/dense/kernel', [1, 35]),
#  ('temporal_conv_net/tblock_1/LayerNorm/beta', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm/gamma', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm_1/beta', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm_1/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm_1/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm_1/gamma', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm_1/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_1/LayerNorm_1/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_1/conv1/bias', [35]),
#  ('temporal_conv_net/tblock_1/conv1/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_1/conv1/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_1/conv1/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_1/conv1/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_1/conv1/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_1/conv2/bias', [35]),
#  ('temporal_conv_net/tblock_1/conv2/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_1/conv2/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_1/conv2/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_1/conv2/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_1/conv2/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_2/LayerNorm/beta', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm/gamma', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm_1/beta', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm_1/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm_1/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm_1/gamma', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm_1/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_2/LayerNorm_1/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_2/conv1/bias', [35]),
#  ('temporal_conv_net/tblock_2/conv1/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_2/conv1/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_2/conv1/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_2/conv1/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_2/conv1/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_2/conv2/bias', [35]),
#  ('temporal_conv_net/tblock_2/conv2/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_2/conv2/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_2/conv2/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_2/conv2/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_2/conv2/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_3/LayerNorm/beta', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm/gamma', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm_1/beta', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm_1/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm_1/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm_1/gamma', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm_1/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_3/LayerNorm_1/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_3/conv1/bias', [35]),
#  ('temporal_conv_net/tblock_3/conv1/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_3/conv1/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_3/conv1/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_3/conv1/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_3/conv1/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_3/conv2/bias', [35]),
#  ('temporal_conv_net/tblock_3/conv2/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_3/conv2/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_3/conv2/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_3/conv2/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_3/conv2/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_4/LayerNorm/beta', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm/gamma', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm_1/beta', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm_1/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm_1/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm_1/gamma', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm_1/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_4/LayerNorm_1/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_4/conv1/bias', [35]),
#  ('temporal_conv_net/tblock_4/conv1/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_4/conv1/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_4/conv1/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_4/conv1/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_4/conv1/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_4/conv2/bias', [35]),
#  ('temporal_conv_net/tblock_4/conv2/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_4/conv2/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_4/conv2/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_4/conv2/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_4/conv2/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_5/LayerNorm/beta', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm/gamma', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm_1/beta', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm_1/beta/Adam', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm_1/beta/Adam_1', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm_1/gamma', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm_1/gamma/Adam', [35]),
#  ('temporal_conv_net/tblock_5/LayerNorm_1/gamma/Adam_1', [35]),
#  ('temporal_conv_net/tblock_5/conv1/bias', [35]),
#  ('temporal_conv_net/tblock_5/conv1/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_5/conv1/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_5/conv1/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_5/conv1/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_5/conv1/kernel/Adam_1', [8, 35, 35]),
#  ('temporal_conv_net/tblock_5/conv2/bias', [35]),
#  ('temporal_conv_net/tblock_5/conv2/bias/Adam', [35]),
#  ('temporal_conv_net/tblock_5/conv2/bias/Adam_1', [35]),
#  ('temporal_conv_net/tblock_5/conv2/kernel', [8, 35, 35]),
#  ('temporal_conv_net/tblock_5/conv2/kernel/Adam', [8, 35, 35]),
#  ('temporal_conv_net/tblock_5/conv2/kernel/Adam_1', [8, 35, 35])]
